# %%
import os
import nltk

# %%
print(os.path.expanduser('~'))
# Out:
# /home/alice

# %%
#try:
#   with open('/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt','r') as f:
#        print(f.read())
#except IOError:
 #   print("No such file exists")

# %%
os.path.dirname('/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt')
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt'

# %%
os.path.join('/home/alice','/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt')
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'

# %%
path = ("/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/")
path
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/'

# %%
# to know the file we are dealing with
os.path.basename('/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/')
# Out:
# ''

# %%
# this can differenciate a directory and a file

os.path.split('/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt')
# Out:
# ('/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt',
#  'Afghanistan 0 18Mar2015.txt')

# %% [markdown]
# #### Definition of localization

# %%
## Set important paths
BASE = os.path.join(os.path.dirname('/home/alice/Documents/Project/info_extraction/scraped_data/txt/Afghanistan 0 18Mar2015.txt'))

# %%
BASE = os.path.join(os.path.dirname("/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt"))

# %%
DOCS = os.path.join(BASE, "scraped_appeals", "files_in_txt")

# %%
DOCS
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/scraped_appeals/files_in_txt'

# %%
BASE
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt'

# %%
path = DOCS

# %%
path
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/scraped_appeals/files_in_txt'

# %%
a = os.listdir(BASE)
a
# Out:
# ['Tanzania MDRTZ016 10Mar2015.txt',
#  'Somalia MDRSO003 24Apr2015.txt',
#  'Afghanistan MDRAF003 05Nov2015.txt',
#  'Philippines 0 18Dec2015.txt',
#  'Peru MAAPE002 01May2015.txt',
#  'Chad MDRTD014 27Mar2015.txt',
#  'Africa regional office MDR60002 08Jan2015.txt',
#  'Timor-Leste MAATP001 27Apr2015.txt',
#  'Malawi MDRMW012 06Dec2016.txt',
#  'Ethiopia MDRET016 31Aug2016.txt',
#  'Belarus MDRBY006 04Jun2015.txt',
#  'Dominican Republic MDRDO009 29Nov2016.txt',
#  'Sudan MDRSD022 10Jul2015.txt',
#  'Hungary MDRHU003 25Feb2015.txt',
#  'Argentina MDRAR010 12Apr2016.txt',
#  'Italy MDRIT002 08May2015.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 19Dec2016.txt',
#  'Paraguay MDRPY017 18Mar2016.txt',
#  'Niger MDRNE013 08Jul2015.txt',
#  "Cote d'Ivoire MDRCI007 04Oct2016.txt",
#  'Vanuatu MDRVU002 14Mar2015.txt',
#  'Greece MDRGR001 11May2016.txt',
#  'Greece MDRGR001 07Dec2015.txt',
#  'Comoro Islands MDRKM005 24Feb2015.txt',
#  'Argentina MDRAR008 26Feb2016.txt',
#  'Italy MDRIT002 09May2015.txt',
#  'Sierra Leone MDRSL005 07Jul2015.txt',
#  'Italy IB210415 24Apr2015.txt',
#  'Ecuador MDREC010 09Dec2015.txt',
#  'Guinea MDRGN007 16Jun2015.txt',
#  'Russia MDRRU018 22Jul2015.txt',
#  'Bosnia and Herzegovina MDRBA009 31Mar2016.txt',
#  'Philippines MDRPH017 27Apr2015.txt',
#  'Serbia MDRRS009 28May2015.txt',
#  'Tanzania MDRTZ017 10May2016.txt',
#  'Viet Nam MDRVN012 23Jan2015.txt',
#  'Ethiopia MDRET016 25Oct2016.txt',
#  'Nepal MDRNP007 27Feb2015.txt',
#  'Madagascar MDRMG011 01Jan2016.txt',
#  'Palestine MDRPS009 03Feb2015.txt',
#  'Sri Lanka MDRLK005 24May2016.txt',
#  'Italy IB021116 02Nov2016.txt',
#  'Indonesia 0 24Feb2016.txt',
#  'Democratic Republic of Congo MDRCD016 19Dec2015.txt',
#  'Libya MDRLY001 11Jan2016.txt',
#  'Central African Republic MDRCF021 07Dec2016.txt',
#  'Kazakhstan MAAKZ001 30Apr2015.txt',
#  'Europe regional office MDR65001 25Oct2016.txt',
#  'Syria MDRSY003 23Sep2016.txt',
#  'Afghanistan MDRAF003 15Dec2015.txt',
#  'Guinea MDRGN007 20Feb2015.txt',
#  'Cameroon MDRCM018 01Jul2015.txt',
#  'Nepal MDRNP008 21Oct2016.txt',
#  'Pakistan MDRPK012 24Aug2016.txt',
#  'Sierra Leone MDRSL006 12Oct2015.txt',
#  'Mongolia MDRMN005 13Jun2016.txt',
#  'Serbia MDRRS011 05Jul2016.txt',
#  'Uruguay MDRUY002 17Nov2016.txt',
#  'Honduras MDRHN008 10Sep2015.txt',
#  'Guinea MDRGN007 05Jan2015.txt',
#  'Myanmar MAAMM002 30Apr2015.txt',
#  'Angola MDRAO006 01Aug2016.txt',
#  'Syria MDRSY003 08Aug2016.txt',
#  'Senegal MDRSN010 20May2015.txt',
#  'Sierra Leone MDRSL005 16Dec2015.txt',
#  'Sudan MAASD001 28Apr2015.txt',
#  'Guinea MDRGN007 18Feb2016.txt',
#  'Philippines 0 12May2015.txt',
#  'Port au Prince country cluster MDR49008 26Jan2016.txt',
#  'Philippines MDRPH017 04Sep2015.txt',
#  'Slovenia MDRSI002 22Dec2015.txt',
#  'Sierra Leone MDRSL005 20Apr2015.txt',
#  'Chile MAACL001 01May2015.txt',
#  'Costa Rica MDRCR014 22Dec2016.txt',
#  'Guyana MDRGY002 06Oct2015.txt',
#  'Suva country cluster MDR55001 23Mar2015.txt',
#  'Paraguay MAAPY001 06May2015.txt',
#  'South Sudan MDRSS003 04Nov2015.txt',
#  '- Global - MDR00001 01Jun2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 06Jun2016.txt',
#  'Dominica MDRDM002 11Sep2015.txt',
#  'Gabon MDRGA007 22Jul2016.txt',
#  'Tajikistan MDRTJ024 30May2016.txt',
#  'Honduras MDRHN008 22Apr2016.txt',
#  'Bangladesh MAABD001 07May2015.txt',
#  'Jamaica MDRJM004 08Oct2016.txt',
#  'Sierra Leone MDRSL006 31May2016.txt',
#  'Croatia MDRHR002 09Feb2016.txt',
#  'Niger MDRNE015 01Feb2016.txt',
#  'Tajikistan MDRTJ020 19Nov2015.txt',
#  'Barbados MAABB001 14May2015.txt',
#  'Ecuador MDREC012 19May2016.txt',
#  'Sudan MDRSD023 11Oct2016.txt',
#  'Sierra Leone MDRSL006 18Sep2015.txt',
#  'Sierra Leone MDRSL005 30Jun2016.txt',
#  'Europe regional office MDR65001 22Apr2016.txt',
#  'Russia MDRRU020 24Oct2016.txt',
#  'Liberia MDRLR002 12Jul2016.txt',
#  'Maldives MDRMV002 15May2015.txt',
#  'Bangladesh MDRBD016 05Aug2016.txt',
#  'Malawi MDRMW011 22Jan2015.txt',
#  'Philippines MDRPH015 30Jan2015.txt',
#  'Bangladesh 0 16Jul2015.txt',
#  'Mozambique MDRMZ012 02Jun2016.txt',
#  'Malaysia MDRMY002 01Jan2015.txt',
#  'Liberia MDRLR001 18Feb2016.txt',
#  'Belize 0 04Aug2016.txt',
#  "Cote d'Ivoire MDRCI009 29Feb2016.txt",
#  'Bangladesh MDRBD014 31Jan2016.txt',
#  'Comoro Islands MDRKM005 09Feb2015.txt',
#  'MENA regional office MDR81003 05Apr2016.txt',
#  'Fiji MDRFJ001 23Sep2016.txt',
#  'Chile MDRCL011 24Jul2015.txt',
#  'Gabon MDRGA007 19Sep2016.txt',
#  'Zimbabwe MDRZW011 27Apr2016.txt',
#  'Guinea MDRGN007 28Jun2015.txt',
#  'Panama MDRPA012 05Dec2016.txt',
#  'Mauritania MDRMR007 15May2015.txt',
#  'Honduras MDRHN008 03Apr2016.txt',
#  'Uganda MDRUG038 26Aug2016.txt',
#  'Nigeria MDRNG020 22Jul2015.txt',
#  'Paraguay MDRPY018 22Sep2016.txt',
#  'Rwanda MDRRW011 04Oct2016.txt',
#  'Sudan MDRSD022 28Aug2015.txt',
#  'Philippines MDRPH020 22Dec2015.txt',
#  'Argentina MDRAR010 23Aug2016.txt',
#  'Liberia MDRLR001 27Apr2016.txt',
#  'Yemen MDRYE005 09Sep2016.txt',
#  'Nigeria MDRNG019 03Nov2015.txt',
#  'Tanzania MDRTZ016 14May2015.txt',
#  'Namibia MDRNA009 23May2016.txt',
#  'Italy MDRIT002 25Mar2016.txt',
#  'Nepal MDRNP008 19Aug2015.txt',
#  'Cuba MDRCU003 03Jun2016.txt',
#  'Honduras MDRHN008 16Mar2015.txt',
#  'Bangladesh MDRBD017 08Aug2016.txt',
#  'Saint Lucia MDRLC003 15Oct2016.txt',
#  'Pakistan MDRPK010 29Jan2015.txt',
#  'Guinea MDRGN007 20Mar2015.txt',
#  'Togo MDRTG006 29Feb2016.txt',
#  'South Sudan MDRSS004 26Jan2016.txt',
#  'Hungary MDRHU004 17Sep2015.txt',
#  'Bangladesh MDRBD017 18Nov2016.txt',
#  'Sierra Leone MDRSL005 14Aug2015.txt',
#  'Philippines MDRPH013 12Jan2015.txt',
#  'Guinea MDRGN007 25Jul2016.txt',
#  'Ukraine MDRUA007 30May2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK003 11Jun2015.txt',
#  'Bolivia MDRBO010 28Feb2016.txt',
#  'Pakistan MDRPK011 29Jul2016.txt',
#  'Sri Lanka MDRLK005 22Dec2016.txt',
#  'Namibia MDRNA009 12Nov2015.txt',
#  'Myanmar MDRMM006 11Aug2015.txt',
#  'Cape Verde MDRCV002 13Feb2015.txt',
#  'Philippines MDRPH020 08Mar2016.txt',
#  'Togo MDRTG006 29Sep2016.txt',
#  'Guinea Bisau MDRGW002 04May2015.txt',
#  'Africa regional office MDR60002 06Mar2015.txt',
#  'Mongolia MDRMN005 25Jul2016.txt',
#  'Guinea MDRGN008 19Oct2015.txt',
#  'Ethiopia MDRET016 25Jan2016.txt',
#  'Syria MDRSY003 31Dec2016.txt',
#  'Suva country cluster MAA55001 30Apr2015.txt',
#  'Senegal MDRSN010 28Feb2015.txt',
#  'Italy IB24082016 24Aug2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK006 17Feb2016.txt',
#  'Kazakhstan MDRKZ008 20Oct2015.txt',
#  'Viet Nam MAAVN001 27Apr2015.txt',
#  'Madagascar MDRMG011 30Sep2015.txt',
#  'Guinea MDRGN007 07Jul2015.txt',
#  'Italy IB301016 30Oct2016.txt',
#  'Zimbabwe MDRZW011 09May2016.txt',
#  'Ukraine MDRUA008 30Dec2015.txt',
#  'Democratic People Republic of Korea MDRKP007 24May2016.txt',
#  'Pakistan MDRPK012 27Nov2015.txt',
#  'Guinea MDRGN007 30Jun2016.txt',
#  'Philippines MDRPH014 22Nov2016.txt',
#  'Viet Nam MDRVN013 08Apr2016.txt',
#  'Vanuatu MDRVU002 16Mar2015.txt',
#  'Liberia MDRLR001 28Jun2015.txt',
#  'Europe IB010216 01Feb2016.txt',
#  'Cameroon MDRCM022 29Apr2016.txt',
#  'Laos MDRLA004 23Sep2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK003 15Jan2015.txt',
#  'Somalia MDRSO005 08Sep2016.txt',
#  'Central African Republic MDRCF017 19Oct2015.txt',
#  'Tanzania MDRTZ017 20Jan2016.txt',
#  'Serbia MDRRS011 18Aug2015.txt',
#  'Nepal MDRNP008 25Feb2016.txt',
#  'India MDRIN014 09Mar2015.txt',
#  'Slovenia MDRSI002 20Jun2016.txt',
#  'Myanmar MDRMM006 17Mar2016.txt',
#  'Liberia MDRLR001 30Jun2016.txt',
#  'El Salvador MDRSV009 23Apr2016.txt',
#  'Iraq MDRIQ006 19Apr2015.txt',
#  'Bangladesh MDRBD015 12Aug2015.txt',
#  'Somalia MDRSO002 23Feb2015.txt',
#  'Afghanistan MDRAF002 11May2015.txt',
#  'Uganda MDRUG032 20Feb2015.txt',
#  'Nigeria MDRNG017 02Apr2015.txt',
#  'Myanmar MDRMM006 27Nov2015.txt',
#  'Liberia MDRLR001 04Sep2015.txt',
#  'Lesotho MDRLS004 26Feb2016.txt',
#  'India MDRIN014 08Jun2015.txt',
#  'Sudan MDRSD016 25Feb2016.txt',
#  'Belize MAABZ001 14May2015.txt',
#  'Albania MDRAL005 06Feb2015.txt',
#  'Honduras MDRHN009 17May2016.txt',
#  'Sudan MDRSD021 10Apr2015.txt',
#  'table_report.txt',
#  'Niger MDRNE014 24Apr2015.txt',
#  'Turkey IB010915 01Sep2015.txt',
#  'Laos MDRLA004 29Aug2016.txt',
#  'Haiti MDRHT013 13Dec2016.txt',
#  'Ethiopia MDRET016 02Jun2016.txt',
#  'Ukraine MDRUA007 25Mar2015.txt',
#  'Europe regional office MDR65001 18Apr2016.txt',
#  'Togo MDRTG005 06Mar2015.txt',
#  'Ghana MDRGH010 30Apr2015.txt',
#  'Hungary MDRHU004 05Apr2016.txt',
#  'Kosovo MAAKV001 30Apr2015.txt',
#  'Malawi MDRMW011 26Feb2015.txt',
#  'Bangladesh MDRBD014 12Feb2015.txt',
#  'El Salvador MDRSV009 27Aug2015.txt',
#  'Mozambique MDRMZ011 20Feb2015.txt',
#  'Pakistan MDRPK012 03Nov2015.txt',
#  'Sri Lanka MDRLK002 19May2015.txt',
#  'Kenya MDRKE036 31May2016.txt',
#  'Dominican Republic MDRDO009 29Dec2016.txt',
#  'Italy IB31082016 31Aug2016.txt',
#  'Nairobi country cluster MDR64007 14Aug2015.txt',
#  'Nigeria MDRNG017 03Sep2015.txt',
#  'Egypt MDREG013 09Nov2016.txt',
#  'Europe regional office MDR65001 04Aug2016.txt',
#  'Solomon Island MDRSB004 18Mar2015.txt',
#  'Kenya MDRKE030 31Aug2015.txt',
#  'Bangladesh MDRBD016 05Jul2016.txt',
#  'Argentina MDRAR009 27Aug2015.txt',
#  'Nepal MDRNP008 14May2015.txt',
#  'Philippines MDRPH019 31May2016.txt',
#  'Ecuador MDREC012 22Apr2016.txt',
#  'Sierra Leone MDRSL005 07Sep2016.txt',
#  'Pakistan MDRPK011 17Feb2016.txt',
#  'Nigeria MDRNG020 11Jun2015.txt',
#  'Bangladesh 0 14Jan2015.txt',
#  'Bolivia MDRBO010 11Jun2015.txt',
#  'Haiti MDRHT012 07Dec2015.txt',
#  'Costa Rica MDRCR012 23Mar2015.txt',
#  'Guinea MDRGN007 25May2016.txt',
#  'Suva country cluster 0 20Feb2016.txt',
#  'Central African Republic MDRCF020 21Apr2016.txt',
#  'Turkmenistan MAATM001 30Apr2015.txt',
#  'Ghana MDRGH013 21Nov2016.txt',
#  'Europe IB206112015 06Nov2015.txt',
#  'Ecuador MDREC011 22Oct2016.txt',
#  'Ethiopia MDRET015 21Sep2015.txt',
#  'Russia MDRRU017 09Jan2015.txt',
#  'Tanzania IBTZ14092016 14Sep2016.txt',
#  'Sierra Leone MDRSL005 20Feb2015.txt',
#  'Malawi MDRMW012 18Apr2016.txt',
#  'Democratic People Republic of Korea MDRKP008 20Sep2016.txt',
#  'Uganda MDRUG037 01Jul2015.txt',
#  'Palestine MAAPS001 05May2015.txt',
#  'Rwanda MDRRW012 11May2015.txt',
#  'Tanzania MDRTZ019 01Jun2016.txt',
#  'Guinea MDRGN007 16Dec2015.txt',
#  'Mongolia 0 17Dec2016.txt',
#  'El Salvador MDRSV007 23Jun2015.txt',
#  'Africa regional office MDR60002 23Jan2015.txt',
#  'Papua New Guinea MDRPG005 17Sep2015.txt',
#  'Peru MDRPE010 07Aug2015.txt',
#  'Zimbabwe MAAZW001 29Apr2015.txt',
#  'Democratic Republic of Congo MDRCD019 25Nov2016.txt',
#  'South Sudan MDRSS003 29Apr2015.txt',
#  'Mongolia MDRMN005 25Oct2016.txt',
#  'India MDRIN016 11Mar2016.txt',
#  'Bangladesh MDRBD017 09Sep2016.txt',
#  'Croatia MDRHR002 11Mar2016.txt',
#  'Burundi MDRBI012 25Oct2016.txt',
#  'Bulgaria MDRBG002 19Feb2015.txt',
#  'Cameroon MDRCM021 14Apr2015.txt',
#  'Philippines MDRPH022 20Dec2016.txt',
#  'Beijing country cluster MAA54001 30Apr2015.txt',
#  'Democratic People Republic of Korea MDRKP008 13Sep2016.txt',
#  'Nairobi country cluster MDR64007 26Jun2015.txt',
#  'Fiji MDRFJ001 01Mar2016.txt',
#  'Kenya MDRKE034 25Nov2015.txt',
#  'Liberia MDRLR001 07Sep2016.txt',
#  'Turkey MDRTR003 22Nov2016.txt',
#  'Port au Prince country cluster MDR49008 04Nov2016.txt',
#  '- Global - MDR42003 01Jun2016.txt',
#  'Burundi MDRBI011 07Apr2015.txt',
#  'Hungary MDRHU004 01Jul2016.txt',
#  'Panama MDRPA011 10Jun2016.txt',
#  'Costa Rica MDRCR012 18Sep2015.txt',
#  'Rwanda MDRRW012 05Aug2015.txt',
#  'Tanzania MDRTZ018 31May2016.txt',
#  'Indonesia 0 07Dec2016.txt',
#  'Sri Lanka MDRLK005 10Jun2016.txt',
#  'Iraq MDRIQ008 08Jul2016.txt',
#  'Guinea MDRGN007 23Jan2015.txt',
#  'Philippines 0 29Apr2016.txt',
#  'Colombia MDRCO011 18Dec2015.txt',
#  'Philippines MDRPH014 07Apr2016.txt',
#  'Armenia MDRAM003 08Jul2016.txt',
#  'Maldives MAAMV001 29Apr2015.txt',
#  'Kenya MDRKE018 25Mar2015.txt',
#  'Kenya MDRKE036 04Jan2016.txt',
#  'India MDRIN017 02Sep2016.txt',
#  'Philippines MDRPH014 18Aug2015.txt',
#  'Argentina MDRAR008 12Jun2015.txt',
#  'Central African Republic MDRCF020 01Aug2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 10Sep2015.txt',
#  'St Vincent and Grenadines MDRVC003 14Dec2016.txt',
#  'Philippines MDRPH011 08Feb2016.txt',
#  'Dakar country cluster MAA61004 05May2015.txt',
#  'Serbia MDRRS012 21Sep2016.txt',
#  'Nicaragua MDRNI006 23Mar2015.txt',
#  'Belarus MAABY002 30Apr2015.txt',
#  'Kenya MDRKE032 30Jun2015.txt',
#  'Europe IB150116 15Jan2016.txt',
#  'Nepal MDRNP008 10Jun2016.txt',
#  '- Global - MAA00040 02Jun2015.txt',
#  '- Global - MAA00040 12May2015.txt',
#  'Ukraine MDRUA008 09May2016.txt',
#  'Viet Nam 0 24Mar2016.txt',
#  'Central African Republic MDRCF020 28Sep2016.txt',
#  'Guinea MDRGN008 12Aug2015.txt',
#  'Italy MDRIT002 02Nov2015.txt',
#  'Afghanistan MAAAF001 03Jun2015.txt',
#  'Guyana MDRGY002 19Nov2015.txt',
#  'Democratic People Republic of Korea MDRKP008 23Sep2016.txt',
#  'Haiti MDRHT013 29Nov2016.txt',
#  'Uruguay MAAUY001 01May2015.txt',
#  'Panama MDRPA010 24Apr2015.txt',
#  'New Zealand 0 15Nov2016.txt',
#  'Kenya MDRKE034 30Oct2015.txt',
#  'Turkey MDRTR003 29Feb2016.txt',
#  'Africa regional office MDR60002 07Jul2015.txt',
#  'Nepal MDRNP008 04Aug2016.txt',
#  'Burundi MDRBI012 18Oct2016.txt',
#  'Philippines MDRPH023 28Dec2016.txt',
#  'Angola MDRAO006 05Jul2016.txt',
#  'Europe regional office MDR65001 01Dec2016.txt',
#  'Togo MDRTG006 06Jun2016.txt',
#  'Somalia MDRSO004 14Nov2015.txt',
#  'Bosnia and Herzegovina MDRBA009 21Oct2015.txt',
#  'Somalia MDRSO004 29Apr2016.txt',
#  'Sri Lanka MDRLK005 25Oct2016.txt',
#  'Tanzania MDRTZ017 06Nov2015.txt',
#  'Sri Lanka MAALK002 30Apr2015.txt',
#  'Afghanistan MDRAF002 15Jan2015.txt',
#  'Guinea MDRGN007 14Aug2015.txt',
#  'Democratic People Republic of Korea MDRKP007 08Sep2015.txt',
#  'Tanzania MDRTZ017 29Jun2015.txt',
#  'Tajikistan MDRTJ020 20May2015.txt',
#  'Uganda MDRUG038 15Sep2016.txt',
#  'Seychelles MDRSC004 20Dec2016.txt',
#  'Viet Nam MDRVN014 18Nov2016.txt',
#  'Europe regional office MDR65001 20Nov2015.txt',
#  'Democratic Republic of Congo MDRCD018 22Jul2016.txt',
#  'Kenya MDRKE039 22Dec2016.txt',
#  'Americas regional office MDR42002 15Sep2015.txt',
#  'Philippines MDRPH014 29Dec2015.txt',
#  'Liberia MDRLR001 15Sep2015.txt',
#  'Paraguay MDRPY018 28Jan2016.txt',
#  'Nigeria MDRNG018 06Nov2015.txt',
#  'Zimbabwe MDRZW011 04Oct2016.txt',
#  'Mauritania MDRMR007 31May2016.txt',
#  'Costa Rica MDRCR014 19Jan2016.txt',
#  'Sierra Leone MDRSL005 23Mar2015.txt',
#  'Cuba MDRCU003 27Aug2016.txt',
#  'Mali MDRML010 14Jan2015.txt',
#  'Myanmar MDRMM007 04Oct2016.txt',
#  'Guinea MDRGN007 15Sep2015.txt',
#  'Bangladesh MDRBD016 16Dec2016.txt',
#  'Liberia MDRLR001 05Apr2016.txt',
#  'Ukraine MDRUA007 03Jun2015.txt',
#  'Zimbabwe MDRZW011 16Sep2015.txt',
#  'MENA regional office MAA80003 29Sep2015.txt',
#  'Ukraine MDRUA008 24May2016.txt',
#  'Africa regional office MDR60002 14Nov2015.txt',
#  'Kenya MDRKE039 25Nov2016.txt',
#  'Myanmar MDRMM007 16Nov2016.txt',
#  'Philippines MDRPH014 14Oct2015.txt',
#  'Rwanda MDRRW013 25Apr2016.txt',
#  'Suva country cluster MDR55001 19Jun2015.txt',
#  'Kenya MDRKE039 24Nov2016.txt',
#  'Pakistan MDRPK011 28Aug2015.txt',
#  'Dominica MDRDM002 28Oct2015.txt',
#  'Lesotho MDRLS004 20Jul2016.txt',
#  "Cote d'Ivoire MDRCI009 21Apr2016.txt",
#  'Africa regional office MDR60002 15Sep2015.txt',
#  'Kiribati MDRKI001 17Mar2015.txt',
#  'India MDRIN015 12Nov2015.txt',
#  'Gambia MDRGM009 04May2015.txt',
#  'Ukraine MDRUA007 24Dec2016.txt',
#  'Serbia MDRRS009 30Nov2015.txt',
#  'Uganda MDRUG038 25Oct2016.txt',
#  'Angola MDRAO006 28Jul2016.txt',
#  'Mali MDRML011 31Jan2016.txt',
#  'India MDRIN017 02Aug2016.txt',
#  'Palestine MDRPS010 03Feb2015.txt',
#  'Burundi MDRBI012 20Apr2016.txt',
#  'Central African Republic MDRCF017 01Dec2015.txt',
#  'India MDRIN015 29Apr2016.txt',
#  'Niger MDRNE014 20Mar2015.txt',
#  'Sudan MDRSD022 31Aug2016.txt',
#  'Djibouti MDRDJ002 09Jul2015.txt',
#  'Burundi MDRBI012 28Apr2016.txt',
#  'Africa regional office MDR60002 20Apr2015.txt',
#  'Pakistan MDRPK011 24Sep2015.txt',
#  'Laos MDRLA004 25Nov2016.txt',
#  'Italy MDRIT002 21Oct2016.txt',
#  'El Salvador MAASV002 02Jul2015.txt',
#  'Paraguay MDRPY016 04Mar2016.txt',
#  'Tunis country cluster MAA82001 29Sep2015.txt',
#  'Italy IB09092016 09Sep2016.txt',
#  'Honduras MAAHN002 26May2015.txt',
#  'Mauritania MDRMR007 01Jul2015.txt',
#  'Senegal MDRSN010 02Apr2015.txt',
#  'Mali MDRML011 02Mar2016.txt',
#  'Ethiopia MDRET016 04Jan2016.txt',
#  'Guatemala MDRGT009 14Nov2016.txt',
#  'Guinea MDRGN008 21Jul2016.txt',
#  'Somalia MDRSO005 25Oct2016.txt',
#  'Tanzania MDRTZ017 23May2015.txt',
#  'Dominican Republic MDRDO008 24Feb2016.txt',
#  'Benin MDRBJ014 02Mar2015.txt',
#  'Greece MDRGR001 01Jul2016.txt',
#  'Timor-Leste MDRTP004 23Sep2016.txt',
#  'Africa regional office MDR60002 27Apr2016.txt',
#  'Macedonia, the former Yugoslav Republic of 0 10Aug2016.txt',
#  'Ecuador MDREC012 18Apr2016.txt',
#  'Timor-Leste MDRTP004 11Nov2016.txt',
#  'Mexico IB24102015 25Oct2015.txt',
#  'Ukraine MDRUA007 05Apr2016.txt',
#  'Philippines MDRPH020 25Jul2016.txt',
#  'Belize MDRBZ005 16Aug2016.txt',
#  'Sierra Leone MDRSL005 15Sep2015.txt',
#  'Benin MDRBJ015 14Sep2016.txt',
#  'Africa regional office MDR60002 09Jan2015.txt',
#  'Zimbabwe MDRZW010 26Aug2015.txt',
#  'Bulgaria MDRBG002 27Apr2015.txt',
#  'Nairobi country cluster - 02May2015.txt',
#  'Venezuela MAAVE002 04May2015.txt',
#  "Cote d'Ivoire MDRCI009 19Oct2015.txt",
#  'Burundi MDRBI011 30Oct2015.txt',
#  'Moldova MAAMD002 30Apr2015.txt',
#  'Nepal MDRNP007 02Jun2015.txt',
#  'Zimbabwe MDRZW011 15Oct2015.txt',
#  'Philippines MDRPH014 23Jun2015.txt',
#  'Peru MDRPE009 23Feb2016.txt',
#  'Albania MDRAL005 04Sep2015.txt',
#  'Belarus MDRBY005 12Jan2015.txt',
#  'Tanzania MDRTZ017 10Jun2015.txt',
#  'Mozambique MDRMZ011 31Mar2016.txt',
#  'Panama MDRPA011 22Mar2016.txt',
#  'Mozambique MDRMZ012 26Jul2016.txt',
#  'Ghana MDRGH011 11Jun2015.txt',
#  'Guatemala MDRGT009 25Oct2016.txt',
#  'Burkina Faso MDRBF013 09Aug2016.txt',
#  'Argentina MDRAR008 24Mar2015.txt',
#  'Guatemala MDRGT007 14Jul2015.txt',
#  'Mongolia 0 08Jan2016.txt',
#  'Philippines MDRPH023 06Jan2017.txt',
#  'Philippines MDRPH016 26Feb2015.txt',
#  'Cameroon MDRCM021 27May2016.txt',
#  'Philippines 0 27Dec2016.txt',
#  'Iraq MDRIQ008 25Oct2016.txt',
#  'Nigeria MDRNG017 02Jun2015.txt',
#  'Sierra Leone MDRSL005 05Apr2016.txt',
#  'Syria MDRSY003 06May2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK007 18Aug2016.txt',
#  'El Salvador MDRSV009 26Nov2015.txt',
#  'Africa regional office MDR60002 18Feb2016.txt',
#  'Afghanistan MDRAF003 26May2016.txt',
#  'Philippines MDRPH011 30Jan2015.txt',
#  'Sudan MDRSD022 01Mar2016.txt',
#  'Haiti MDRHT008 05Apr2016.txt',
#  'Sudan MDRSD022 18Jun2016.txt',
#  'Pakistan MDRPK012 29Jan2016.txt',
#  'Rwanda MDRRW011 21Apr2015.txt',
#  'Fed. States of Micronesia MDRFM001 04Sep2015.txt',
#  'Cameroon MDRCM021 04Apr2016.txt',
#  'South Sudan MAASS001 28Apr2015.txt',
#  'Dominica MDRDM002 08Apr2016.txt',
#  'Niger MDRNE015 10Jul2015.txt',
#  'Cameroon MDRCM021 03Jul2015.txt',
#  'Ethiopia MDRET015 28Jun2016.txt',
#  'Myanmar MDRMM007 19Aug2016.txt',
#  'Solomon Island MDRSB003 11Apr2015.txt',
#  'Sri Lanka MDRLK002 25Nov2015.txt',
#  'Kenya MDRKE030 25Nov2015.txt',
#  'Cameroon MDRCM024 07Nov2016.txt',
#  'Central African Republic MDRCF019 27Nov2015.txt',
#  'Macedonia, the former Yugoslav Republic of IB 07082015 07Aug2015.txt',
#  'Hungary MDRHU004 05Oct2016.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 04Oct2016.txt',
#  'Honduras MDRHN010 30Sep2016.txt',
#  'Sierra Leone MDRSL005 17Jun2015.txt',
#  'Tanzania MDRTZ020 20Sep2016.txt',
#  'Central African Republic MDRCF019 30Mar2016.txt',
#  'Myanmar MDRMM006 04Jan2017.txt',
#  'Senegal MDRSN010 15May2015.txt',
#  'Bangladesh 0 21May2016.txt',
#  'Philippines MDRPH018 03Apr2015.txt',
#  'Chile MDRCL010 04Mar2015.txt',
#  'Africa regional office MDR60002 15May2015.txt',
#  'Africa regional office MDR60002 20Feb2015.txt',
#  'Bangladesh MDRBD016 25May2016.txt',
#  'Sudan MDRSD023 28Nov2016.txt',
#  'Mongolia MAAMN001 30Apr2015.txt',
#  'Viet Nam MDRVN013 28Jun2016.txt',
#  'Belize MDRBZ004 03Nov2015.txt',
#  'Indonesia MDRID010 27Nov2015.txt',
#  'Rwanda MDRRW013 05Oct2015.txt',
#  'Philippines MDRPH019 21Oct2015.txt',
#  'Yemen MAAYE001 29Sep2015.txt',
#  'Burundi MDRBI012 18Nov2016.txt',
#  'Belize MDRBZ004 21Dec2016.txt',
#  'Namibia MDRNA009 25Oct2016.txt',
#  'Sudan MDRSD022 22Dec2016.txt',
#  'Belarus MDRBY006 04Aug2016.txt',
#  'Cape Verde MDRCV002 18Dec2015.txt',
#  'Sudan MDRSD020 03May2015.txt',
#  'Liberia MDRLR001 06Feb2015.txt',
#  'Ecuador MDREC008 23Oct2015.txt',
#  'Israel MDRIL002 21Jan2015.txt',
#  'Armenia MDRAM003 08Dec2016.txt',
#  'Philippines MDRPH022 25Oct2016.txt',
#  'Zimbabwe MDRZW010 02Apr2015.txt',
#  'Sierra Leone MDRSL005 18Mar2015.txt',
#  'Ecuador 0 17Apr2016.txt',
#  'Lesotho MDRLS004 22Jan2016.txt',
#  'Nigeria MDRNG017 20Feb2015.txt',
#  'Fed. States of Micronesia MDRFM001 04Apr2015.txt',
#  'Rwanda MDRRW013 17Jul2016.txt',
#  'Greece MDRGR001 04Sep2015.txt',
#  'Seychelles MDRSC004 18Aug2016.txt',
#  'Yemen Yemen Floods IB 2016 18Apr2016.txt',
#  'Timor-Leste MDRTP004 08Jul2016.txt',
#  'Nepal MDRNP008 11May2015.txt',
#  'Solomon Island MDRSB003 09Jul2015.txt',
#  'Fiji MDRFJ001 05Aug2016.txt',
#  'Kenya MDRKE018 31Mar2016.txt',
#  'Liberia MDRLR001 06Mar2015.txt',
#  'Kenya MDRKE033 02Jun2015.txt',
#  'Mozambique MDRMZ011 08Sep2015.txt',
#  'Viet Nam MDRVN013 07Nov2016.txt',
#  'South Sudan MDRSS004 05Oct2015.txt',
#  'Liberia MDRLR001 25May2016.txt',
#  'Tajikistan MDRTJ022 28Jul2015.txt',
#  'Mongolia MDRMN005 01Mar2016.txt',
#  'Honduras MDRHN008 01Jul2015.txt',
#  'Georgia MDRGE010 23Jun2015.txt',
#  'Pakistan MDRPK010 24Feb2016.txt',
#  'Ethiopia MDRET014 02Jul2015.txt',
#  'Russia MAARU002 30Apr2015.txt',
#  'Central and Western Europe country cluster IB230315 25Mar2015.txt',
#  'Ethiopia MDRET015 29Apr2016.txt',
#  'Fed. States of Micronesia 0 01Apr2015.txt',
#  '- Global - MDR42003 02Feb2016.txt',
#  '- Global - MAA00006 24Apr2015.txt',
#  'Africa regional office MDR60002 16Oct2015.txt',
#  'Africa regional office MDR60002 03Nov2015.txt',
#  'Africa regional office MDR60002 06Feb2015.txt',
#  'Turkey MDRTR003 05Jun2015.txt',
#  'Haiti MDRHT011 14Jun2016.txt',
#  'Gambia MDRGM011 17Dec2016.txt',
#  'India MDRIN015 14Aug2015.txt',
#  'Djibouti MDRDJ002 01Feb2016.txt',
#  'Pretoria country cluster MAA63001 04May2015.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK004 04Sep2015.txt',
#  'Senegal MDRSN010 06Mar2015.txt',
#  'Chile MDRCL011 01Mar2016.txt',
#  'Bangladesh MDRBD014 20Nov2015.txt',
#  'Philippines MDRPH019 26Feb2016.txt',
#  'Tajikistan MDRTJ023 14Jun2016.txt',
#  'Maldives 0 30Jan2016.txt',
#  'Bolivia MDRBO010 13Mar2015.txt',
#  'Greece MDRGR001 21Oct2015.txt',
#  'Serbia MDRRS011 19Dec2016.txt',
#  'Tanzania MDRTZ017 20May2015.txt',
#  'Croatia MDRHR002 08Aug2016.txt',
#  'Nigeria MDRNG020 08Mar2015.txt',
#  'Guinea MDRGN007 16Oct2015.txt',
#  'Nigeria MDRNG017 23Jan2015.txt',
#  'Tajikistan MAATJ002 30Apr2015.txt',
#  'Colombia MDRCO011 12Sep2015.txt',
#  'Abuja country cluster MAA61002 30Apr2015.txt',
#  'Philippines MDRPH014 31Jan2015.txt',
#  'Djibouti MDRDJ002 29Apr2015.txt',
#  'Nairobi country cluster MAA64002 29Apr2015.txt',
#  'Yaounde country cluster MAA62001 29Apr2015.txt',
#  'Pakistan MDRPK011 18Dec2015.txt',
#  'South Sudan MDRSS005 24Oct2016.txt',
#  'Iran IB Iran Floods April 2016 20Apr2016.txt',
#  'France IB141115 14Nov2015.txt',
#  'Cameroon MDRCM019 04May2015.txt',
#  'Serbia MDRRS011 28Oct2015.txt',
#  'Democratic Republic of Congo MDRCD016 20Sep2016.txt',
#  'Europe IB21215 02Dec2015.txt',
#  'Cape Verde MDRCV002 22Apr2016.txt',
#  'Sri Lanka MDRLK002 05Jun2015.txt',
#  'India MDRIN016 30Jun2016.txt',
#  'Italy IB271016 27Oct2016.txt',
#  'Africa regional office MDR60002 14Aug2015.txt',
#  'Bangladesh MDRBD015 11Dec2015.txt',
#  'Malawi MDRMW012 27Apr2016.txt',
#  'Guyana MDRGY002 27Apr2016.txt',
#  'Costa Rica MDRCR014 25Oct2016.txt',
#  'Niger MDRNE013 04Aug2016.txt',
#  'Liberia MDRLR001 20Apr2015.txt',
#  'South Sudan MDRSS005 01Aug2016.txt',
#  'Gambia MDRGM011 29Nov2016.txt',
#  'Rwanda MDRRW012 30May2016.txt',
#  'Bangladesh MDRBD017 17Aug2016.txt',
#  'Fed. States of Micronesia MDRFM001 23Jun2015.txt',
#  'Mongolia MDRMN005 15Jan2016.txt',
#  'Philippines MDRPH019 06Nov2015.txt',
#  'Guatemala MDRGT008 31Mar2016.txt',
#  'Myanmar 0 11Aug2016.txt',
#  'Mozambique MDRMZ012 27May2016.txt',
#  "Cote d'Ivoire MDRCI007 24Apr2015.txt",
#  'Croatia MDRHR001 27Apr2016.txt',
#  'Sudan MDRSD016 22Jun2015.txt',
#  'Democratic People Republic of Korea MDRKP008 27Oct2016.txt',
#  'Philippines MDRPH019 30Dec2015.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 01Dec2016.txt',
#  'Ecuador MDREC011 27Sep2016.txt',
#  'Turkey MDRTR003 07Apr2015.txt',
#  'Hungary MDRHU004 06Aug2015.txt',
#  'Kenya MDRKE037 09May2016.txt',
#  'Bolivia MAABO001 01May2015.txt',
#  'Eritrea MAAER002 03May2015.txt',
#  'Chile 0 30Mar2015.txt',
#  'Iraq Information Bulletin 1 - Iraq 02Jul2016.txt',
#  'India MDRIN015 05Apr2016.txt',
#  'Malawi MDRMW011 28Feb2015.txt',
#  'Somalia MDRSO005 25Mar2016.txt',
#  'Yemen MDRYE005 22Apr2016.txt',
#  'Guinea MDRGN007 06Mar2015.txt',
#  'Costa Rica MDRCR014 04May2016.txt',
#  'Fiji MDRFJ001 28Apr2016.txt',
#  'Rwanda MDRRW012 01Sep2015.txt',
#  'Guatemala MDRGT008 09Oct2015.txt',
#  'Nigeria MDRNG018 04Oct2016.txt',
#  'Suva country cluster 0 18Mar2015.txt',
#  'Ecuador MDREC012 24Jun2016.txt',
#  'Democratic People Republic of Korea 0 03Sep2016.txt',
#  'Ghana MDRGH011 30Jun2016.txt',
#  'Philippines 0 25Dec2016.txt',
#  "Cote d'Ivoire MDRCI007 14Dec2015.txt",
#  'Algeria MDRDZ002 08Apr2016.txt',
#  'Zimbabwe MDRZW011 18Sep2015.txt',
#  'Somalia MDRSO003 02Jul2015.txt',
#  'Pakistan MDRPK011 13Aug2015.txt',
#  'Europe regional office MDR65001 07Mar2016.txt',
#  'Fiji MDRFJ001 23Feb2016.txt',
#  'Suva country cluster MDR55001 21Jul2015.txt',
#  'India MAAIN001 29Apr2015.txt',
#  'Nigeria MDRNG017 06Mar2015.txt',
#  'Liberia MDRLR001 14Nov2015.txt',
#  'Uruguay MDRUY002 28Apr2016.txt',
#  'Nairobi country cluster MDR64007 30Sep2016.txt',
#  'Lebanon MDRLB005 12Jan2015.txt',
#  'Liberia MDRLR001 16Dec2015.txt',
#  'Georgia MDRGE010 18Dec2015.txt',
#  'New Delhi country cluster 0 27Oct2015.txt',
#  'Greece MDRGR001 07Oct2016.txt',
#  'Nepal MDRNP007 20Nov2015.txt',
#  'Malaysia MDRMY002 25Jun2015.txt',
#  'Kenya MDRKE037 05Oct2016.txt',
#  '- Global - MAA00028 01May2015.txt',
#  'Greece MDRGR001 27Jul2015.txt',
#  'Liberia MDRLR002 13Sep2016.txt',
#  'Ethiopia MDRET016 05Feb2016.txt',
#  'Sierra Leone MDRSL005 25May2016.txt',
#  'Sierra Leone MDRSL005 14Nov2015.txt',
#  'Ecuador MDREC009 24Feb2016.txt',
#  '- Global - MAA00021 02Jun2015.txt',
#  'Dominican Republic MDRDO009 22Dec2016.txt',
#  'Djibouti MDRDJ002 31Oct2016.txt',
#  'Central African Republic MDRCF017 30Sep2016.txt',
#  'Nairobi country cluster IB 15Apr2015.txt',
#  'Uganda MDRUG038 16Nov2016.txt',
#  '- Global - MDR00001 21Apr2015.txt',
#  'El Salvador MDRSV010 03Mar2016.txt',
#  'Zimbabwe MDRZW011 24Mar2016.txt',
#  'Tajikistan MDRTJ021 17Dec2015.txt',
#  'Dominican Republic MDRDO008 18May2016.txt',
#  'Somalia MDRSO005 30Dec2016.txt',
#  'Mozambique MDRMZ012 31Dec2016.txt',
#  'Americas regional office MAA42003 26Jan2016.txt',
#  'Guatemala MDRGT008 22Apr2016.txt',
#  'Niger MDRNE013 13Dec2016.txt',
#  'Central African Republic MDRCF020 19Feb2016.txt',
#  'Nepal MDRNP008 07Jul2015.txt',
#  'Mozambique MDRMZ012 27Apr2016.txt',
#  'Liberia MDRLR001 15May2015.txt',
#  'Guatemala MAAGT002 02Jul2015.txt',
#  'Haiti MDRHT008 19Nov2015.txt',
#  'Haiti MDRHT011 03Aug2016.txt',
#  'India MDRIN016 01Dec2015.txt',
#  'Colombia MDRCO011 22Apr2016.txt',
#  'Sri Lanka MDRLK005 21May2016.txt',
#  'Burundi MDRBI012 06Apr2016.txt',
#  'Ecuador MDREC010 11Mar2016.txt',
#  'Tanzania MDRTZ018 19Dec2015.txt',
#  'Timor-Leste MDRTP004 18May2016.txt',
#  'Democratic Republic of Congo - 22Jun2015.txt',
#  'Angola MDRAO006 06Jun2016.txt',
#  'Cameroon MDRCM021 30Sep2015.txt',
#  'Armenia MAAAM002 30Apr2015.txt',
#  'Central African Republic MDRCF019 12Aug2015.txt',
#  'Fiji MDRFJ001 15Dec2016.txt',
#  'Philippines MDRPH022 04Nov2016.txt',
#  'Dominica MDRDM002 04Sep2015.txt',
#  'Uganda MDRUG037 30Apr2015.txt',
#  'Kenya MDRKE035 22Sep2015.txt',
#  'Cape Verde MDRCV002 06May2015.txt',
#  'Bolivia MDRBO010 05Nov2015.txt',
#  'Belize MDRBZ004 18Feb2016.txt',
#  'Greece MDRGR001 02Sep2015.txt',
#  'India MDRIN016 13Jan2016.txt',
#  'Tanzania MDRTZ018 11Dec2015.txt',
#  'Seychelles MDRSC004 09Jun2016.txt',
#  'Malawi MDRMW012 26Oct2015.txt',
#  'Mauritania MDRMR007 30Sep2016.txt',
#  'Russia MDRRU019 24Apr2015.txt',
#  'Malawi MDRMW012 29Sep2015.txt',
#  'Malawi MDRMW011 17Jul2015.txt',
#  'Guatemala MDRGT007 10Mar2016.txt',
#  'Senegal MDRSN010 20Apr2015.txt',
#  'Ethiopia MDRET014 02Feb2015.txt',
#  'Guatemala IB03102015 03Oct2015.txt',
#  'Guinea MDRGN007 07Sep2016.txt',
#  'Kenya MDRKE018 05Oct2016.txt',
#  'Suva country cluster MDR55001 31Mar2016.txt',
#  '- Global - MAA00010 10Nov2015.txt',
#  'Bolivia MDRBO009 04Mar2015.txt',
#  'Ecuador MDREC010 21Jul2016.txt',
#  'Kosovo MDRXK001 24Nov2016.txt',
#  'Kenya MDRKE031 08Apr2015.txt',
#  'Sudan MDRSD016 19Feb2015.txt',
#  'Cameroon MDRCM022 31Mar2016.txt',
#  'Costa Rica MAACR001 18Jun2015.txt',
#  'Niger MDRNE013 30Jun2016.txt',
#  'Nigeria MDRNG017 06Feb2015.txt',
#  'Papua New Guinea MDRPG005 30Oct2015.txt',
#  'Nairobi country cluster MDR64007 05Jun2015.txt',
#  'Syria MDRSY003 09Dec2015.txt',
#  'Georgia MAAGE002 30Apr2015.txt',
#  'Sierra Leone MDRSL005 20Mar2015.txt',
#  '- Global - MDR42003 22Jun2016.txt',
#  'Lebanon MDRLB004 29Jul2016.txt',
#  'Italy MDRIT002 27Apr2015.txt',
#  'Madagascar MDRMG011 02Feb2015.txt',
#  'Iraq MDRIQ008 17Oct2016.txt',
#  'Ethiopia MDRET017 19Aug2016.txt',
#  'Bangladesh MDRBD016 25Oct2016.txt',
#  'Suva country cluster 0 13Mar2015.txt',
#  'Kenya MDRKE038 09Aug2016.txt',
#  'Somalia MDRSO005 11Apr2016.txt',
#  'Georgia MDRGE009 31Mar2015.txt',
#  'Tanzania MDRTZ020 15Oct2016.txt',
#  'Sierra Leone MDRSL005 06Aug2015.txt',
#  'Peru MDRPE011 27Aug2016.txt',
#  'Philippines MDRPH014 13Nov2015.txt',
#  'Malawi MDRMW012 27May2016.txt',
#  'Serbia MDRRS012 07Apr2016.txt',
#  'Croatia MDRHR002 22Jun2016.txt',
#  'Rwanda MDRRW013 28Oct2015.txt',
#  'Sudan MDRSD022 18Aug2015.txt',
#  'Russia MDRRU020 21Jun2016.txt',
#  'Kenya MDRKE035 01Jun2016.txt',
#  'Bahamas MDRBS002 15Dec2015.txt',
#  'Sierra Leone MDRSL005 02Apr2015.txt',
#  'Solomon Island MDRSB006 24Dec2016.txt',
#  'Nigeria MDRNG018 21Jan2016.txt',
#  'Rwanda MDRRW012 01Feb2016.txt',
#  'Costa Rica MDRCR013 07Jul2015.txt',
#  'Kyrgyzstan MAAKG001 30Apr2015.txt',
#  'Liberia MDRLR001 02Apr2015.txt',
#  'Cameroon MDRCM021 09Feb2015.txt',
#  'Iraq MDRIQ007 01Dec2015.txt',
#  'Lesotho MDRLS004 08Feb2016.txt',
#  'Lesotho MDRLS004 06Apr2016.txt',
#  'Costa Rica MDRCR013 17Mar2016.txt',
#  'Colombia MDRCO010 19Feb2015.txt',
#  'Tajikistan MDRTJ023 14Dec2015.txt',
#  'Mozambique MDRMZ011 21Apr2015.txt',
#  'Nigeria MDRNG019 28May2015.txt',
#  'Chile MDRCL011 11Apr2015.txt',
#  'Syria MDRSY003 08Feb2016.txt',
#  'Mauritania MDRMR007 26Jun2015.txt',
#  "Cote d'Ivoire MDRCI008 11Sep2015.txt",
#  'Guinea MDRGN007 15May2015.txt',
#  'Mongolia MDRMN005 31Mar2016.txt',
#  'Ecuador MDREC008 26Jun2015.txt',
#  'Mexico IB23102015 23Oct2015.txt',
#  'Guinea MDRGN007 27Apr2016.txt',
#  'Dominican Republic MDRDO008 14Nov2016.txt',
#  'Ethiopia MDRET015 27Aug2015.txt',
#  'Tanzania MDRTZ018 12Nov2015.txt',
#  'Namibia MDRNA009 03Aug2016.txt',
#  'Tajikistan MDRTJ024 17Nov2016.txt',
#  'Afghanistan 0 02Nov2015.txt',
#  'Ghana MDRGH011 01Jan2016.txt',
#  'Belize MDRBZ005 08Aug2016.txt',
#  'Costa Rica MDRCR014 29Jul2016.txt',
#  'Nepal MDRNP008 16May2015.txt',
#  'Ecuador MDREC011 17Feb2016.txt',
#  'Tuvalu MDRTV001 17Mar2015.txt',
#  'Senegal MDRSN012 22Sep2016.txt',
#  'Myanmar MDRMM006 29Aug2015.txt',
#  'Italy MDRIT002 23Jul2015.txt',
#  'Bangladesh MDRBD015 16Sep2015.txt',
#  'Tajikistan MDRTJ021 17Jun2015.txt',
#  'Kenya MDRKE031 22Jul2015.txt',
#  'Kenya MDRKE018 02Oct2015.txt',
#  'Philippines MDRPH021 19Oct2016.txt',
#  'Ethiopia MDRET015 06Nov2015.txt',
#  'Ecuador MDREC009 12Aug2015.txt',
#  'Nigeria MDRNG018 23Jan2015.txt',
#  'Bosnia and Herzegovina MAABA002 30Apr2015.txt',
#  'Guatemala MDRGT009 28Jun2016.txt',
#  '- Global - MAA00029 21Jun2016.txt',
#  'Argentina MDRAR010 22Jan2016.txt',
#  'Africa regional office MAA60005 05Aug2015.txt',
#  'Cameroon MDRCM020 29May2015.txt',
#  'Americas 0 17Sep2016.txt',
#  'Angola MDRAO006 24Feb2016.txt',
#  'Palestine MDRPS010 22Jun2015.txt',
#  'Cameroon MDRCM020 03Jul2015.txt',
#  'Central African Republic MDRCF018 01May2015.txt',
#  'Nigeria MDRNG017 20Mar2015.txt',
#  'Sierra Leone MDRSL005 08Jan2015.txt',
#  'Europe regional office MAA65001 30Apr2015.txt',
#  'Malawi MDRMW011 23Sep2016.txt',
#  'Paraguay MDRPY017 10Aug2015.txt',
#  'Albania MDRAL006 22Nov2016.txt',
#  'Ghana MDRGH012 08Nov2016.txt',
#  'Sierra Leone MDRSL005 27Apr2016.txt',
#  'Pakistan MAAPK002 29Apr2015.txt',
#  'Philippines MDRPH022 22Oct2016.txt',
#  'Indonesia MDRID010 29Dec2015.txt',
#  'Africa regional office MDR60002 02Apr2015.txt',
#  'Lebanon MDRLB005 24Apr2015.txt',
#  'Philippines MDRPH023 29Dec2016.txt',
#  'Ecuador MAAEC001 04May2015.txt',
#  'Cameroon MDRCM023 11Oct2016.txt',
#  'Ecuador MDREC012 11Nov2016.txt',
#  'Guatemala MDRGT009 05Nov2015.txt',
#  'Kenya MDRKE035 02Oct2015.txt',
#  'Africa regional office MDR60002 25May2016.txt',
#  'Senegal MDRSN010 20Mar2015.txt',
#  'Senegal MDRSN010 06Feb2015.txt',
#  'Haiti MDRHT012 06Jul2015.txt',
#  'Mozambique MDRMZ011 27May2016.txt',
#  'Yemen IB310315Yemen 31Mar2015.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK004 12Feb2015.txt',
#  'Lebanon MDRLB005 31Aug2015.txt',
#  'Africa regional office MDR60002 07Sep2016.txt',
#  'Belarus MDRBY005 28May2015.txt',
#  'Niger MDRNE016 01Oct2016.txt',
#  'Nairobi country cluster MDR64007 13Apr2015.txt',
#  'Democratic Republic of Congo MDRCD015 04May2015.txt',
#  'Liberia MDRLR001 24Jan2016.txt',
#  'Sri Lanka 0 18May2016.txt',
#  'Azerbaijan MAAAZ002 30Apr2015.txt',
#  '- Global - MAA00040 10Nov2015.txt',
#  'Europe regional office MDR65001 07Jun2016.txt',
#  'Nepal MDRNP008 07Dec2015.txt',
#  'Port au Prince country cluster MDR49008 16Oct2015.txt',
#  'Zambia MDRZM009 02Jul2015.txt',
#  'Japan 0 16Apr2016.txt',
#  'Paraguay MDRPY015 22Mar2016.txt',
#  'Bangkok country cluster MAA51001 29Apr2015.txt',
#  'Somalia MDRSO005 25Apr2016.txt',
#  'Fed. States of Micronesia MDRFM001 26Feb2016.txt',
#  'Jordan MDRJO001 04Aug2015.txt',
#  'Turkey IB090216 09Feb2016.txt',
#  'Argentina MAAAR001 01May2015.txt',
#  'Costa Rica MDRCR014 24Dec2015.txt',
#  'Italy IB210415 21Apr2015.txt',
#  'Bahamas MDRBS002 16Oct2015.txt',
#  'Macedonia, the former Yugoslav Republic of MDRMK005 26Jun2015.txt',
#  'Costa Rica MDRCR014 24Nov2015.txt',
#  'Tajikistan MDRTJ022 28Jan2016.txt',
#  'Serbia MDRRS011 13Sep2016.txt',
#  'Suva country cluster MDR55001 09Oct2015.txt',
#  'Solomon Island MDRSB005 02Nov2016.txt',
#  'Nepal MDRNP008 19Jul2016.txt',
#  'Sierra Leone MDRSL005 24Jan2016.txt',
#  'Syria MDRSY003 01Dec2016.txt',
#  'Dominican Republic MAADO001 01Jun2015.txt',
#  'Myanmar MDRMM006 19Oct2015.txt',
#  'Serbia MDRRS011 16Feb2016.txt',
#  'Philippines MDRPH016 29Jul2015.txt',
#  'Viet Nam MDRVN014 28Oct2016.txt',
#  'Brazil MDRBR007 30Oct2015.txt',
#  'Kenya MDRKE034 07Apr2015.txt',
#  'Fiji MDRFJ001 12Mar2016.txt',
#  'Timor-Leste MDRTP004 18Apr2016.txt',
#  'Hungary MDRHU005 29Nov2016.txt',
#  'Indonesia MDRID011 12Dec2016.txt',
#  'Dominica IB280815 29Aug2015.txt',
#  'Nigeria MDRNG017 08Jan2015.txt',
#  'Iran IB floods Iran 22Jul2015.txt',
#  'Guinea MDRGN007 06Feb2015.txt',
#  'Philippines 0 16Dec2015.txt',
#  'Nigeria MDRNG018 11Mar2016.txt',
#  'Sierra Leone MDRSL005 18Feb2016.txt',
#  'Djibouti MDRDJ002 18Sep2015.txt',
#  'Niger MDRNE014 07Dec2015.txt',
#  'Bangladesh MDRBD015 24Jun2016.txt',
#  'Dominica MDRDM002 21Jan2016.txt',
#  'Chile MDRCL010 24Mar2015.txt',
#  'Port of Spain country cluster 0 29Sep2016.txt',
#  'El Salvador MDRSV009 24Dec2015.txt',
#  'Liberia MDRLR001 07Jul2015.txt',
#  'Africa regional office MDR60002 16Jun2015.txt',
#  'Chad MDRTD014 30Oct2015.txt',
#  'Chad MDRTD013 08Apr2015.txt',
#  'Peru MDRPE008 23Feb2016.txt',
#  'Cameroon MDRCM022 17Nov2015.txt',
#  'Suva country cluster MDR55001 26Jan2016.txt',
#  'Lebanon MDRLB004 17Aug2015.txt',
#  'Sierra Leone MDRSL006 01May2016.txt',
#  'Philippines MDRPH014 29Dec2016.txt',
#  'Serbia MDRRS011 09Sep2015.txt',
#  'Somalia - 20Apr2015.txt',
#  'Democratic Republic of Congo MDRCD017 18Jul2016.txt',
#  'Benin MDRBJ014 20Mar2015.txt',
#  'Namibia MDRNA009 30Sep2015.txt',
#  'Zimbabwe MDRZW011 29Sep2015.txt',
#  'Argentina MDRAR010 14Dec2016.txt',
#  'Europe regional office MDR65001 23Jun2016.txt',
#  'Philippines MDRPH013 20Jul2015.txt',
#  'Chad MAATD001 31May2015.txt',
#  'Paraguay MDRPY017 28Apr2015.txt',
#  'Africa regional office MDR60002 16Dec2015.txt',
#  'Mongolia 0 07Dec2015.txt',
#  'Democratic Republic of Congo MDRCD016 02Mar2016.txt',
#  'Morocco MDRMA006 21Jan2015.txt',
#  'Zambia MDRZM009 15Jan2015.txt',
#  'Guyana MDRGY002 01Aug2015.txt',
#  'Tanzania MDRTZ020 01Dec2016.txt',
#  'Sierra Leone MDRSL005 19Oct2015.txt',
#  'Somalia MDRSO004 30May2016.txt',
#  'Syria MDRSY003 07Jul2015.txt',
#  'Americas IB22112016 23Nov2016.txt',
#  'Indonesia MAAID002 27Apr2015.txt',
#  'Bangladesh MDRBD014 20May2015.txt',
#  'Nicaragua MAANI002 21May2015.txt',
#  'Morocco MDRMA006 09Jun2015.txt',
#  'Sri Lanka MDRLK005 01Jul2016.txt',
#  'Mozambique MDRMZ011 04Nov2015.txt',
#  '- Global - MDR42003 25Oct2016.txt',
#  'Ukraine MAAUA002 30Apr2015.txt',
#  'Niger MDRNE015 02Jun2015.txt',
#  'Timor-Leste MDRTP004 26Aug2016.txt',
#  'Mozambique MDRMZ011 26Jan2015.txt',
#  'Tanzania MDRTZ016 17Jun2015.txt',
#  'Malawi MDRMW011 22Jul2015.txt',
#  'Liberia MDRLR001 23Jan2015.txt',
#  'Philippines MDRPH018 09May2015.txt',
#  'Turkey MDRTR003 13Nov2015.txt',
#  'Palestine MDRPS010 30Mar2015.txt',
#  'Croatia MDRHR001 02Oct2015.txt',
#  'Cameroon MDRCM015 27Aug2015.txt',
#  'Nairobi country cluster - 18May2015.txt',
#  'Central African Republic MDRCF018 27Mar2015.txt',
#  'Democratic Republic of Congo MDRCD017 20May2016.txt',
#  'Chile MDRCL012 12Jan2016.txt',
#  'Serbia MDRRS010 27May2015.txt',
#  'Mozambique MDRMZ012 25Oct2016.txt',
#  'Sri Lanka MDRLK002 24Jun2016.txt',
#  'Namibia MDRNA009 03May2016.txt',
#  'Peru MDRPE010 01Mar2016.txt',
#  'Liberia MDRLR001 08Sep2016.txt',
#  'Myanmar MDRMM006 30Jun2016.txt',
#  'Bangladesh MDRBD016 04Jun2016.txt',
#  'Gambia MDRGM010 19Jan2016.txt',
#  'Nigeria MDRNG020 01Dec2015.txt',
#  'Sudan MDRSD023 25Oct2016.txt',
#  'Taiwan 0 09Jul2016.txt',
#  'Tanzania MDRTZ019 29Apr2016.txt',
#  'Chile MDRCL012 22Apr2016.txt',
#  'Guinea MDRGN007 24Jan2016.txt',
#  'Nepal MDRNP008 02May2015.txt',
#  'Tanzania MDRTZ019 08Mar2016.txt',
#  'Senegal MDRSN011 02Jun2015.txt',
#  'Macedonia, the former Yugoslav Republic of IB030115 03Jan2015.txt',
#  'Fiji MDRFJ001 25Oct2016.txt',
#  'Asia Pacific 0 17Feb2016.txt',
#  'Ethiopia MDRET015 31Jan2015.txt',
#  'Cuba MAACU002 22May2015.txt',
#  ...]

# %%
#To open pdf
#import webbrowser
#webbrowser.open_new(r'file:/home/alice/Documents/Project/info_extraction/scraped_data/scraped_appeals/Belarus MDRBY005 12Jan2015.pdf')

# %%
address = os.listdir(BASE)

# %%
len(address)
# Out:
# 1261

# %%
DOCS
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/scraped_appeals/files_in_txt'

# %%
def get_documents(path=BASE):
    """
    Returns a filtered list of paths to PDF files representing our corpus.
    """
    for name in os.listdir(path):
        if name.startswith('') and name.endswith('.txt'):
            yield os.path.join(path, name)
print(len(list(get_documents()))) # the number of Pdf files started by P
# Out:
# 1260

# %% [markdown]
# # NLTK corpus

# %%
CORPUS = os.path.join(BASE, "", "corpus")
CORPUS
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus'

# %%
path = "/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/"
path
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/'

# %%
import re
import codecs
import string
import subprocess
import unicodedata

# %%
## Create a path to extract the corpus.
CORPUS = os.path.join("/home/alice/Documents/Project/info_extraction/scraped_data", "corpus")
CORPUS
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/corpus'

# %%
CORPUS
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/corpus'

# %%
#fname = os.path.splitext(os.path.basename("/home/alice/Documents/Project/info_extraction/scraped_data/Malawi MDRMW012 06Dec2016"))[0] + ".txt"
fname =' /home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'
fname
# Out:
# ' /home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'

# %%
def extract_corpus(BASE,CORPUS):
    for path in get_documents(BASE):
        example_file = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Tanzania MDRTZ016 10Mar2015.txt'
        document = document = open(example_file, 'r').read()
        print(len(document))

# %%
example_file = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'
print(example_file)
# Out:
# /home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt

# %%
#example_file = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Tanzania MDRTZ016 10Mar2015.txt'

# %%
document = open(example_file, 'r').read()
print(len(document))
# Out:
# 9014

# %%
document = filter(
            lambda char: char in string.printable,
            unicodedata.normalize('NFKD', document)
        )
len(list(document))
# Out:
# 8990

# %%
9014-8990
# Out:
# 24

# %%
#document = filter(
 #          lambda char: char in string.printable,
 #           unicodedata.normalize('NFKD', example_file)
 #       )
#len(list(document))

# %%
#fname = os.path.splitext(os.path.basename(path))[0] + ".txt"

# %%
fname
# Out:
# ' /home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'

# %%
corpus = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'
corpus
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'

# %%
#outpath = os.path.join(corpus, fname)
outpath = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'
outpath
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'

# %%
os.path.basename(path)
# Out:
# ''

# %%
corpus
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'

# %%
fname
# Out:
# ' /home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'

# %%
corpus
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'

# %%
example_file
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'

# %%
corpus
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/corpus/'

# %%
def new_corpus(BASE,CORPUS):
    #for path in get_documents(BASE):
        example_file = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/Afghanistan 0 18Mar2015.txt'
        document = document = open(example_file, 'r').read()
        print(len(document))
        document = filter(
            lambda char: char in string.printable,
            unicodedata.normalize('NFKD', document)
        )
        document = ''.join(list(document))
        print(document[:100])
        fname = os.path.basename(example_file)
        print(fname)
        outpath = os.path.join(CORPUS, fname)
        print(outpath)

        with codecs.open(outpath, 'w') as f:
            f.write(document)

# %%
path
# Out:
# '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/'

# %%
new_corpus(BASE, CORPUS)
# Out:
# 9014
# Information Bulletin n 1
# Glide n AV-2015-000016-AFG
# 18 March 2015
# This bulletin is being issued
# for
# Afghanistan 0 18Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Afghanistan 0 18Mar2015.txt

# %%
def all_corpus(BASE,CORPUS):
    for path in get_documents(BASE):
        #all_files = '/home/alice/Documents/Project/info_extraction/scraped_data/files_in_txt/'
        document = open(path, 'r').read()
        print(len(document))
        document = filter(
            lambda char: char in string.printable,
            unicodedata.normalize('NFKD', document)
        )
        document = ''.join(list(document))
        print(document[:100])
        fname = os.path.basename(path)
        print(fname)
        outpath = os.path.join(CORPUS, fname)
        print(outpath)

        with codecs.open(outpath, 'w') as f:
            f.write(document)

# %%
all_corpus(BASE,CORPUS)
# Out:
# 19448
# Tanzania Red Cross Society providing first aid and
# ambulance services in Mwakata village. Photo/TRCS
# Tanzania MDRTZ016 10Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ016 10Mar2015.txt
# 31044
# DREF n MDRSO003 Glide n OT-2015-000047-SOM
# Date of issue: 24/04/2015 Date of disaster: 28 March 2015
# Somalia MDRSO003 24Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Somalia MDRSO003 24Apr2015.txt
# 38439
# DREF Operation n MDRAF003 GLIDE n EQ-2015-000147-AFG
# Date of issue: 5 November 2015 Date of disaster
# Afghanistan MDRAF003 05Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Afghanistan MDRAF003 05Nov2015.txt
# 9813
# Information bulletin no
#
# 2 Glide number no
#
# TC-2015-000168-PHL
# Date of issue: 18 December 2015
# Host
# Philippines 0 18Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines 0 18Dec2015.txt
# 26525
# Overview
# The regional representation for the Andean countries (regional representation) of the Inter
# Peru MAAPE002 01May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Peru MAAPE002 01May2015.txt
# 36341
# DREF Operation n MDRTD014. Operations update n 1
# Date of issue: 27 March, 2015. Period covered by th
# Chad MDRTD014 27Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Chad MDRTD014 27Mar2015.txt
# 20717
# 8 January, 2015- Combined Ebola Operations Update No
# 131
# Summary
# Five emergency appeals were launche
# Africa regional office MDR60002 08Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Africa regional office MDR60002 08Jan2015.txt
# 38563
# Overview
# Cruz Vermelha de Timor-Leste (CVTL) achieved a number of significant milestones in 2014 tha
# Timor-Leste MAATP001 27Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Timor-Leste MAATP001 27Apr2015.txt
# 28318
# Emergency appeal n MDRMW012 GLIDE n DR-2015-000136-MWI
# EPoA update n2: 6 December 2016 Timeframe cov
# Malawi MDRMW012 06Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Malawi MDRMW012 06Dec2016.txt
# 44473
# Emergency appeal n MDRET016 GLIDE n DR-2015-000109-ETH
# 6 month operations update
# Date of issue: 31 A
# Ethiopia MDRET016 31Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET016 31Aug2016.txt
# 1256
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Belarus MDRBY006 04Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Belarus MDRBY006 04Jun2015.txt
# 1146
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Dominican Republic MDRDO009 29Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Dominican Republic MDRDO009 29Nov2016.txt
# 1169
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Sudan MDRSD022 10Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sudan MDRSD022 10Jul2015.txt
# 25299
# DREF operation final report Operation n MDRHU003
# Glide n FL-2014000130-HUN
# Date of issue: 25 Februar
# Hungary MDRHU003 25Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Hungary MDRHU003 25Feb2015.txt
# 47839
# Emergency appeal no. MDRAR010 GLIDE no. FL-2016-000003-ARG
# Operations update no. 1, 12 April 2016 Ti
# Argentina MDRAR010 12Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Argentina MDRAR010 12Apr2016.txt
# 18017
# Appeal n MDRIT002 85,000 people to be assisted Appeal launched May 2015
# Glide n OT-2015-000050-ITA C
# Italy MDRIT002 08May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy MDRIT002 08May2015.txt
# 25163
# This Operations Update no. 4 reports on the latest
# activities carried out by the Red Cross of the fo
# Macedonia, the former Yugoslav Republic of MDRMK005 19Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK005 19Dec2016.txt
# 61899
# 1
# DREF Operation no. MDRPY017 Glide no. ST-2015-000041-PRY
# Date of issue: 18 March 2016 Date of disa
# Paraguay MDRPY017 18Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Paraguay MDRPY017 18Mar2016.txt
# 28320
# Emergency Appeal n
# MDRNE013
# Glide n OT-2014-000126-
# NER
# 50,000 people to be assisted
# CHF 851,786 Rev
# Niger MDRNE013 08Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Niger MDRNE013 08Jul2015.txt
# 32832
# P a g e | 1
# DREF Operation: MDRCI007 Glide n: EP-2014-000039-CIV
# Date of issue : 03 October 2016
# Ope
# Cote d'Ivoire MDRCI007 04Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cote d'Ivoire MDRCI007 04Oct2016.txt
# 18339
# DREF operation n
# o
# : MDRVU002 Glide n
# o
# TC-2015-000020-VUT
# Date of issue: 13 March 2015 Date of disa
# Vanuatu MDRVU002 14Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Vanuatu MDRVU002 14Mar2015.txt
# 37900
# Revised Appeal n MDRGR001
# Glide n OT-2015-000050-GRC
# 304,000 people to be assisted1
# 296,549 Swiss fr
# Greece MDRGR001 11May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Greece MDRGR001 11May2016.txt
# 57341
# This operations update is to report on the implementation progress of the activities under the revis
# Greece MDRGR001 07Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Greece MDRGR001 07Dec2015.txt
# 27461
# DREF operation Operation n MDRKM005; Glide n EC-2014-000046-COM
# Date of Issue: 24 February, 2015. Da
# Comoro Islands MDRKM005 24Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Comoro Islands MDRKM005 24Feb2015.txt
# 52498
# 1
# DREF No. MDRAR008 MDRAR008 Glide no. FL-2015-000024-ARG
# Date of issue: 26 February 2016 Date of di
# Argentina MDRAR008 26Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Argentina MDRAR008 26Feb2016.txt
# 5786
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Italy MDRIT002 09May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy MDRIT002 09May2015.txt
# 53209
# Combined Ebola Operations Update
# No
# 231
# Reporting period: 1  28 June 2015
# Summary
# IFRCs Ebola strate
# Sierra Leone MDRSL005 07Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 07Jul2015.txt
# 5025
# Information Bulletin n 2
# 23 April 2015
# This bulletin is being issued for
# information only, and refle
# Italy IB210415 24Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy IB210415 24Apr2015.txt
# 35412
# DREF operation MDREC010
# Date issued: 9 December 2015 Date of disaster: 19 November 2015
# Operation ma
# Ecuador MDREC010 09Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ecuador MDREC010 09Dec2015.txt
# 46870
# Combined Ebola Operations Update
# No
# 221
# Reporting period: 11 May  31 May 2015
# Summary
# IFRCs Ebola st
# Guinea MDRGN007 16Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 16Jun2015.txt
# 36729
# DREF operation final report Operation n MDRRU018
# Date of issue: 22 July 2015 Glide n OT-2014-000146-
# Russia MDRRU018 22Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Russia MDRRU018 22Jul2015.txt
# 54791
# Emergency Appeal Operation n MDRBA009
# Final Report
# Glide n FF-2014-000059-BiH
# Date of issue of final
# Bosnia and Herzegovina MDRBA009 31Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bosnia and Herzegovina MDRBA009 31Mar2016.txt
# 20856
# DREF n MDRPH017 DREF allocated: CHF 119,798
# DREF Operation update n 1:
# Issued on 27 April 2015
# Timef
# Philippines MDRPH017 27Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH017 27Apr2015.txt
# 20103
# Emergency appeal n MDRRS009 GLIDE n FF-2014-000059-SRB
# Operations update n 4
# Date of issue: 28 May 2
# Serbia MDRRS009 28May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Serbia MDRRS009 28May2015.txt
# 35126
# Emergency Appeal n MDRTZ017 Glide n OT-2015-000052-TZA
# Operations update n 4
# Period covered by this
# Tanzania MDRTZ017 10May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ017 10May2016.txt
# 76091
# 1
# Emergency appeal n MDRVN012
# GLIDE n TC-2013-000122-VNM
# 3 January 2015
# Period covered by this Final
# Viet Nam MDRVN012 23Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Viet Nam MDRVN012 23Jan2015.txt
# 1586
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Ethiopia MDRET016 25Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET016 25Oct2016.txt
# 63888
# Emergency appeal n MDRNP007 GLIDE n  FL-2014-000112-NPL
# Operations update n 2
# Date of issue: 27 Febr
# Nepal MDRNP007 27Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal MDRNP007 27Feb2015.txt
# 61364
# This final report has been reissued due to a transaction adjustment done on the final financial
# repo
# Madagascar MDRMG011 01Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Madagascar MDRMG011 01Jan2016.txt
# 29940
# A. Situation analysis
# Description of the disaster
# Since the suspension of peace talks
# between Israel
# Palestine MDRPS009 03Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Palestine MDRPS009 03Feb2015.txt
# 25983
# Appeal n MDRLK005
# Glide n FL-2016-000050-LKA
# 40,000 people to be assisted
# 249,443 Swiss francs DREF
# Sri Lanka MDRLK005 24May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sri Lanka MDRLK005 24May2016.txt
# 4370
# Date of issue: 2 November 2016
# Date of disaster:
# 30 October 2016
# Point of contact: Ruben Romero, DM
# Italy IB021116 02Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy IB021116 02Nov2016.txt
# 10533
# Date of issue: 24 February 2016
# Information bulletin n 2
# GLIDE n FL-2016-000009-IDN
# This bulletin is
# Indonesia 0 24Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Indonesia 0 24Feb2016.txt
# 26329
# A. Situation analysis
# Description of the disaster
# In the Democratic Republic of Congo (DRC), extensi
# Democratic Republic of Congo MDRCD016 19Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic Republic of Congo MDRCD016 19Dec2015.txt
# 27661
# DREF operation  Final Report Operation n MDRLY001
# Date of Issue: 11/01/2016 Glide n CE-2014-000108-L
# Libya MDRLY001 11Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Libya MDRLY001 11Jan2016.txt
# 48011
# Emergency appeal n MDRCF021 Operations Update n 1
# Date of issue: 7 December 2016 Timeframe covered b
# Central African Republic MDRCF021 07Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Central African Republic MDRCF021 07Dec2016.txt
# 29881
# Overview
# In order to strengthen the specific Red Cross / Red Crescent contribution to development, t
# Kazakhstan MAAKZ001 30Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kazakhstan MAAKZ001 30Apr2015.txt
# 2033
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Europe regional office MDR65001 25Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Europe regional office MDR65001 25Oct2016.txt
# 23857
# KPMG SA
# Geneva, 15 September 2016
# Ref. PHP/KV
# International Federation of Red Cross
# and Red Crescent
# Syria MDRSY003 23Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Syria MDRSY003 23Sep2016.txt
# 21098
# ARCS volunteers distributing NFIs to earthquake affected families
# in Nangarhar province in Eastern r
# Afghanistan MDRAF003 15Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Afghanistan MDRAF003 15Dec2015.txt
# 41791
# 20 February, 2015 - Combined Ebola Operations Update No
# 161
# Summary
# IFRCs Ebola strategic framework
# Guinea MDRGN007 20Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 20Feb2015.txt
# 47834
# DREF operation: MDRCM018 Glide number: EP-2014-000100-CMR
# Date of Issue: 30 June 2015 Date of disast
# Cameroon MDRCM018 01Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cameroon MDRCM018 01Jul2015.txt
# 82020
# Emergency appeal n MDRNP008
# EQ-2015-000048-NPL
# Operation update n12
# 20 October 2016
# Emergency appeal
# Nepal MDRNP008 21Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal MDRNP008 21Oct2016.txt
# 31762
# A. Situation analysis
# Description of the disaster
# A massive earthquake of 7.5 magnitude struck North
# Pakistan MDRPK012 24Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Pakistan MDRPK012 24Aug2016.txt
# 42830
# DREF n MDRSL006 GLIDE n FL-2015-000131-SLE
# EPoA update n 1; 12 October 2015 Timeframe covered by thi
# Sierra Leone MDRSL006 12Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL006 12Oct2015.txt
# 22773
# Emergency appeal n MDRMN005 GLIDE n CW-2016-000004-MNG
# Operations update n 2
# Issued on 13 June 2016
#
# Mongolia MDRMN005 13Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Mongolia MDRMN005 13Jun2016.txt
# 28376
# Relief distribution near Kelebija border crossing.
# Photo: Red Cross of Serbia
# Appeal n MDRRS011 196,
# Serbia MDRRS011 05Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Serbia MDRRS011 05Jul2016.txt
# 33380
# P a g e | 1
# DREF Operation N MDRUY002 Glide no. FL-2016-000041-URY
# Date of issue: 17 November 2016 D
# Uruguay MDRUY002 17Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Uruguay MDRUY002 17Nov2016.txt
# 30131
# Support has been provided to the reactivation of the agricultural livelihoods
# of 250 producers. Sour
# Honduras MDRHN008 10Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Honduras MDRHN008 10Sep2015.txt
# 24168
# Emergency appeal n MDRGN007 GLIDE n EP-2014-000039-GIN
# Operation Manager (responsible for this EPoA)
# Guinea MDRGN007 05Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 05Jan2015.txt
# 63631
# Overview
# With a target goal of 294,655 vulnerable people to be reached in 2014, a total of 337,323 (
# Myanmar MAAMM002 30Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Myanmar MAAMM002 30Apr2015.txt
# 28106
# Emergency appeal n MDRAO006 Glide n EP-2015-000179-AGO
# Operations update n 2
# Date of issue: 31 July
# Angola MDRAO006 01Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Angola MDRAO006 01Aug2016.txt
# 59011
# 0 | P a g e
# Emergency appeal n MDRSY003 GLIDE n OT-2011-000025-SYR
# Operations update n 11 Timeframe
# Syria MDRSY003 08Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Syria MDRSY003 08Aug2016.txt
# 24880
# Emergency appeal n MDRSN010 GLIDE n EP-2014-000039-SEN
# 6 month update Timeframe covered by this upda
# Senegal MDRSN010 20May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Senegal MDRSN010 20May2015.txt
# 69602
# Combined Monthly Ebola Operations Update No
# 281
# 15 December 2015
# Current epidemiological
# situation +
# Sierra Leone MDRSL005 16Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 16Dec2015.txt
# 10888
# Overview
# Throughout the reporting period, the IFRC continued to provide technical and financial supp
# Sudan MAASD001 28Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sudan MAASD001 28Apr2015.txt
# 39378
# Combined Monthly Ebola Operations Update No
# 311
# 18 March 2016
# Current epidemiological situation +
# co
# Guinea MDRGN007 18Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 18Feb2016.txt
# 5047
# Information Bulletin n 2
# GLIDE n TC-2015-000051-PHL
# 12 May 2015
# This bulletin is being issued for in
# Philippines 0 12May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines 0 12May2015.txt
# 26226
# P a g e | 1
# Hand washing activity in Colombier/October 2015. Source IFRC
# International Appeal (MDR49
# Port au Prince country cluster MDR49008 26Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Port au Prince country cluster MDR49008 26Jan2016.txt
# 12486
# DREF operation n MDRPH017 Date of issuing this report: 4 September 2015
# Date of disaster: 2 March 20
# Philippines MDRPH017 04Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH017 04Sep2015.txt
# 31783
# DREF n MDRSI002 GLIDE n OT-2015-000069-SVN
# EPoA update n 1;
# date of issue: 22 December 2015
# Timefram
# Slovenia MDRSI002 22Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Slovenia MDRSI002 22Dec2015.txt
# 37641
# 20 April 2015 - Combined Ebola Operations Update No
# 201
# 30 March  12 April 2015
# Summary
# IFRCs Ebola
# Sierra Leone MDRSL005 20Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 20Apr2015.txt
# 35230
# O
# T
# th
# C
# N
# in
# p
# a
# P
# D
# w
# V
# p
# C
# p
# 3
# D
# T
# N
# s
# o
# im
# tr
# T
# Overview
# The secreta
# hrough its
# Chilean Red
# Nati
# Chile MAACL001 01May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Chile MAACL001 01May2015.txt
# 56537
# Emergency Appeal Operations Update No. 3 (12-month
# update)
# Emergency appeal no. MDRCR014
# GLIDE no. O
# Costa Rica MDRCR014 22Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Costa Rica MDRCR014 22Dec2016.txt
# 28113
# A flooded street, yard and home in
# Georgetown. Source: The Guyana Red Cross
# Society
# Click here to vi
# Guyana MDRGY002 06Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guyana MDRGY002 06Oct2015.txt
# 40241
# International Appeal n MDR55001 81,000 people to be assisted Appeal launched 23 March 2015
# CHF 575,0
# Suva country cluster MDR55001 23Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Suva country cluster MDR55001 23Mar2015.txt
# 31775
# Overview
# The secretariat of the International Federation of Red Cross and Red Crescent Societies (IF
# Paraguay MAAPY001 06May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Paraguay MAAPY001 06May2015.txt
# 69171
# Emergency Appeal Operation n MDRSS003
# Date of Issue: 30 October 2015 Glide number: OT-2014-000001-SS
# South Sudan MDRSS003 04Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/South Sudan MDRSS003 04Nov2015.txt
# 56541
# 1
# Overview
# Statistics on use of DREF 2015 Number Amount in CHF
# Total of allocations made 1241
# 19,762
# - Global - MDR00001 01Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/- Global - MDR00001 01Jun2016.txt
# 29472
# Revised Appeal n MDRMK005
# Glide n OT-2015-000069-MKD
# People to be assisted:
# First phase (until March
# Macedonia, the former Yugoslav Republic of MDRMK005 06Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK005 06Jun2016.txt
# 13329
# Appeal no. MDRDM002
# Glide no. TC-2015-000119-DMA
# 12,000 people to be assisted
# CHF 169,560 DREF alloc
# Dominica MDRDM002 11Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Dominica MDRDM002 11Sep2015.txt
# 24192
# DREF Operation MDRGA007
# Date of Issue: 22.07.2016 Date of Disaster: 15 July  28 August 2016
# Operatio
# Gabon MDRGA007 22Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Gabon MDRGA007 22Jul2016.txt
# 27007
# DREF n MDRTJ024 GLIDE n MS-2016-000049-TJK
# DREF operations update n 1
# Issued on 30 May 2016
# Timefram
# Tajikistan MDRTJ024 30May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tajikistan MDRTJ024 30May2016.txt
# 42399
# P a g e | 1
# Emergency Appeal for Drought in Honduras Operation no. MDRHN008
# Date issued: 22 April 20
# Honduras MDRHN008 22Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Honduras MDRHN008 22Apr2016.txt
# 25662
# MAABD001
# 29 April 2015
# This report covers the
# period 1 January to 31
# December 2014
# Participants in t
# Bangladesh MAABD001 07May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MAABD001 07May2015.txt
# 22861
# P a g e | 1
# DREF Operation Operation no. MDRJM004
# Date of issue: 7 October 2016 Date of disaster: 3
# Jamaica MDRJM004 08Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Jamaica MDRJM004 08Oct2016.txt
# 42097
# SLRCS volunteers distributed NFIs to flood affected families in
# 5 districts. IFRC/2016.
# DREF operati
# Sierra Leone MDRSL006 31May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL006 31May2016.txt
# 18215
# Appeal no. MDRHR002 175,000 people to be assisted Appeal launched 9 February 2016
# Glide no. OT-2015-
# Croatia MDRHR002 09Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Croatia MDRHR002 09Feb2016.txt
# 23667
# DREF Operation n MDRNE015 Glide n EP-2015-000043-NER
# Date of Issue: 1 February, 2016 Date of disaste
# Niger MDRNE015 01Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Niger MDRNE015 01Feb2016.txt
# 32432
# DREF operation final report Operation n MDRTJ020
# Date of issue: 19 November 2015 Glide n FL-2015-000
# Tajikistan MDRTJ020 19Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tajikistan MDRTJ020 19Nov2015.txt
# 38312
# Overview
# During the reporting period, the Barbados Red Cross Society (BRCS) engaged in one major dis
# Barbados MAABB001 14May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Barbados MAABB001 14May2015.txt
# 34718
# Operations Update no. 2 Operation no. MDREC012; Glide no. EQ-2016-
# 000035-ECU
# Date of issue: 19 May
# Ecuador MDREC012 19May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ecuador MDREC012 19May2016.txt
# 21057
# P a g e | 1
# Appeal Operation n MDRSD023 Glide n FL-2016-000072-SDN
# Operation update No. 2 Period cov
# Sudan MDRSD023 11Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sudan MDRSD023 11Oct2016.txt
# 26855
# | 1
# P a g e
# A. Situation analysis
# Description of the disaster
# Sustained heavy downpour of rain from
# Sierra Leone MDRSL006 18Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL006 18Sep2015.txt
# 44247
# Combined Monthly Ebola Operations Update
# No
# 341
# 30 June 2016
# Current epidemiological situation,
# coun
# Sierra Leone MDRSL005 30Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 30Jun2016.txt
# 72038
# 1
# Combined Monthly Europe Population Movement update1
# Issued on 22 April 2016
# MDR65001 Europe: Migra
# Europe regional office MDR65001 22Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Europe regional office MDR65001 22Apr2016.txt
# 19034
# 1
# DREF n MDRRU020 GLIDE n FL-2016-000061-RUS
# Operations Update n 1
# Timeframe covered by this update:
# Russia MDRRU020 24Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Russia MDRRU020 24Oct2016.txt
# 26777
# P a g e | 1
# LNRCS staff and volunteers distributing NFIs to flood affected
# households. Photo: LNRCS
#
# Liberia MDRLR002 12Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR002 12Jul2016.txt
# 31971
# P a g e | 1
# DREF n MDRMV0002 GLIDE n AC-2014-000161-MDV
# Issue on: 15 May 2015 Timeframe covered by t
# Maldives MDRMV002 15May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Maldives MDRMV002 15May2015.txt
# 52846
# Emergency appeal n MDRBD016 GLIDE n TC-2016-000052-BGD
# Operations update n 2 Timeframe covered by th
# Bangladesh MDRBD016 05Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD016 05Aug2016.txt
# 20383
# Appeal n MDRMW011 42,130 people to be assisted Appeal launched January 2015
# 274,000 DREF allocated
# G
# Malawi MDRMW011 22Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Malawi MDRMW011 22Jan2015.txt
# 17146
# DREF operation: MDRPH015 GLIDE n TC-2014-000092-PHL
# Date of issue: 30 January 2015 Date of disaster:
# Philippines MDRPH015 30Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH015 30Jan2015.txt
# 9218
# Information Bulletin n 1
# GLIDE n FL-2015-000068
# 16 July 2015
# This bulletin is being issued for infor
# Bangladesh 0 16Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh 0 16Jul2015.txt
# 19266
# Maize crop failure like this is easily seen in drought hard-
# hit provinces. Photo by IFRC in Mabalan
# Mozambique MDRMZ012 02Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Mozambique MDRMZ012 02Jun2016.txt
# 16418
# DREF Operation n MDRMY002 Glide n FL-2014-000168-MYS
# Date of issue: 1 January 2015 Date of disaster:
# Malaysia MDRMY002 01Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Malaysia MDRMY002 01Jan2015.txt
# 39378
# Combined Monthly Ebola Operations Update No
# 311
# 18 March 2016
# Current epidemiological situation +
# co
# Liberia MDRLR001 18Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 18Feb2016.txt
# 7697
# Date of issue: 4 August 2016, 1:00PM (CDT)
# Date of disaster: 4 August 2016
# Point of contact (name an
# Belize 0 04Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Belize 0 04Aug2016.txt
# 32046
# DREF Operation Operation n MDRCI009
# Date of issue: 29 February, 2016 Date of disaster: 24 - 30 Octob
# Cote d'Ivoire MDRCI009 29Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cote d'Ivoire MDRCI009 29Feb2016.txt
# 80653
# Emergency appeal n MDRBD014
# GLIDE n FL-2014-000117-BGD
# Final report
# 31 January 2016
# Reporting period
# Bangladesh MDRBD014 31Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD014 31Jan2016.txt
# 27139
# DREF operation Operation n MDRKM005; Glide n EC-2014-000046-COM
# Date of Issue: 9 February, 2015 Date
# Comoro Islands MDRKM005 09Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Comoro Islands MDRKM005 09Feb2015.txt
# 25591
# International Federation of Red Cross
# and Red Crescent Societies (IFRC), Geneva
# Independent Auditors
# MENA regional office MDR81003 05Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/MENA regional office MDR81003 05Apr2016.txt
# 39048
# P a g e | 1
# Emergency appeal n MDRFJ001 GLIDE n TC-2016-000014-FJI
# Operations update n3 - 6-month up
# Fiji MDRFJ001 23Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Fiji MDRFJ001 23Sep2016.txt
# 56242
# Distribution of humanitarian aid in the province of Chanaral
# Source: Chilean Red Cross
# DREF Operatio
# Chile MDRCL011 24Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Chile MDRCL011 24Jul2015.txt
# 36376
# Page 1 of 10
# DREF n MDRGA007 EPoA update n 1
# Date of issue: 19 September 2016 Timeframe covered by t
# Gabon MDRGA007 19Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Gabon MDRGA007 19Sep2016.txt
# 24967
# Photo of destroyed crops in the affected farming
# districts
# Appeal n MDRZW011 38,330 people to be ass
# Zimbabwe MDRZW011 27Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Zimbabwe MDRZW011 27Apr2016.txt
# 21629
# Revised Emergency Appeal n 4
# MDRGN007
# Glide n EP-2014-000039-GIN
# 12.7 million people to be assisted
#
# Guinea MDRGN007 28Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 28Jun2015.txt
# 28270
# DREF Operation Operation n MDRPA012
# Glide n TC-2016-000119-PAN
# Date of issue: 05 December 2016 Date
# Panama MDRPA012 05Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Panama MDRPA012 05Dec2016.txt
# 33362
# Emergency Appeal n MDRMR007 10,400 people immediate assistance,
# 27,000 medium-term assistance
# CHF 99
# Mauritania MDRMR007 15May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Mauritania MDRMR007 15May2015.txt
# 43012
# P a g e | 1
# Emergency Appeal for Drought in Honduras Operation no. MDRHN008
# Date issued: 3 April 201
# Honduras MDRHN008 03Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Honduras MDRHN008 03Apr2016.txt
# 25798
# Appeal n MDRUG038
# Glide n OT-2016-000087-UGA
# 40,000 people to be assisted
# 658,782 Swiss francs curre
# Uganda MDRUG038 26Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Uganda MDRUG038 26Aug2016.txt
# 6308
# DREF Appeal n MDRNG020;GLIDE n EP-2014-000055-NGA
# EPoA update n 2; Date of issue: 22 July
# 2015.
# Peri
# Nigeria MDRNG020 22Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nigeria MDRNG020 22Jul2015.txt
# 20178
# Revised Appeal n MDRPY018
# Glide n FL-2016-000171-PRY
# 24,560 people (4,912 families) to be assisted
# 2
# Paraguay MDRPY018 22Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Paraguay MDRPY018 22Sep2016.txt
# 35228
# DREF operation: MDRRW011 Glide n FL-2015-000042-RWA
# Date of Issue: 29 September 2016 Date of disaste
# Rwanda MDRRW011 04Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Rwanda MDRRW011 04Oct2016.txt
# 25524
# Emergency appeal Appeal n MDRSD022;GLIDE n: CE-2013-000061-SDN
# Operations update: n2
# Date of Issue:
# Sudan MDRSD022 28Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sudan MDRSD022 28Aug2015.txt
# 26423
# Emergency Appeal n MDRPH020 Glide n TC-2015-000168-PHL & TC-2015-000170-PHL
# Date of issue: 22 Decemb
# Philippines MDRPH020 22Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH020 22Dec2015.txt
# 18724
# Revised Appeal n MDRAR010
# Glide n FL-2016-000003-ARG
# 12,500 people (2,500 families) to be assisted
# 1
# Argentina MDRAR010 23Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Argentina MDRAR010 23Aug2016.txt
# 44208
# Combined Monthly Ebola Operations Update No
# 321
# 27 April 2016
# Current epidemiological situation,
# cou
# Liberia MDRLR001 27Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 27Apr2016.txt
# 20190
# Operations update
# Yemen: Flash floods
# This operations update presents the implementation of the acti
# Yemen MDRYE005 09Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Yemen MDRYE005 09Sep2016.txt
# 38732
# DREF operation n: MDRNG019 Glide number: NA
# Date of Issue: 31 October 2015 Date of disaster: 15 Febr
# Nigeria MDRNG019 03Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nigeria MDRNG019 03Nov2015.txt
# 21950
# DREF Operation Appeal n MDRTZ016
# Operation update n 1 Period covered by this update: 4 March to 2 Ma
# Tanzania MDRTZ016 14May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ016 14May2015.txt
# 28170
# Emergency Appeal n MDRNA009 GLIDE n
# o
# DR-2015-000130-NAM
# Six month summary update
# Date of issue: 23
# Namibia MDRNA009 23May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Namibia MDRNA009 23May2016.txt
# 44919
# Emergency appeal n MDRIT002
# Operations update n 2
# GLIDE n OT-2015-000050-ITA
# Date of issue: 25 March
# Italy MDRIT002 25Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy MDRIT002 25Mar2016.txt
# 6300
# 1
# Revised Appeal MDRNP008
# GLIDE no EQ-2015-000048-NPL
# Operation Update no 6
# Issue on: 19 August 2015
# Nepal MDRNP008 19Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal MDRNP008 19Aug2015.txt
# 40398
# P a g e | 1
# DREF Operation MDRCU003
# Date of issue: 2 June 2016 Date of disaster: May 2016
# Responsibl
# Cuba MDRCU003 03Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cuba MDRCU003 03Jun2016.txt
# 11502
# Revised Appeal no. MDRHN008 17,500 people to be assisted
# Appeal launched 13 October 2014
# This revisi
# Honduras MDRHN008 16Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Honduras MDRHN008 16Mar2015.txt
# 46151
# DREF Operation n MDRBD017 Glide n FL-2016-000075-BD
# Date of issue: 8 August 2016 Date of disaster: 2
# Bangladesh MDRBD017 08Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD017 08Aug2016.txt
# 18912
# DREF Operation Operation N MDRLC003
# Date of issue: 14 October 2016 Date of disaster: 29 September 20
# Saint Lucia MDRLC003 15Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Saint Lucia MDRLC003 15Oct2016.txt
# 12267
# Emergency Appeal n MDRPK010 Glide n FL-2014-000122-PAK Issued: 29 January 2015
# 70,000 people to be a
# Pakistan MDRPK010 29Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Pakistan MDRPK010 29Jan2015.txt
# 43298
# 20 March 2015 - Combined Ebola Operations Update No
# 181
# 1  15 March 2015
# Summary
# IFRCs Ebola strateg
# Guinea MDRGN007 20Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 20Mar2015.txt
# 26433
# W
# DREF Operation Operation n MDRTG006; Glide n EP-2016-000015-
# TGO
# Date of issue: 29 February 2016 D
# Togo MDRTG006 29Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Togo MDRTG006 29Feb2016.txt
# 38382
# DREF operation Preliminary Final Report Operation n MDRSS004
# Date of Issue: 26 January 2016 Glide nu
# South Sudan MDRSS004 26Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/South Sudan MDRSS004 26Jan2016.txt
# 16241
# Appeal n MDRHU004 120,000 people to be assisted Appeal launched 17 September 2015
# Glide n OT-2015-00
# Hungary MDRHU004 17Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Hungary MDRHU004 17Sep2015.txt
# 49632
# Emergency appeal operations update
# Bangladesh: Floods
# Emergency appeal n MDRBD017 GLIDE n FL-2016-00
# Bangladesh MDRBD017 18Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD017 18Nov2016.txt
# 47011
# Combined Ebola Operations
# Update No
# 241
# Reporting period:
# Summary
# IFRCs Ebola strategic
# framework is
# Sierra Leone MDRSL005 14Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 14Aug2015.txt
# 50618
# 1
# Emergency appeal n MDRPH013
# GLIDE n EQ-2013-000134-PHL
# Operation update no5
# 12 January 2015
# Period
# Philippines MDRPH013 12Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH013 12Jan2015.txt
# 38980
# Revised Appeal n MDRGN007 298,410 people to be assisted
# recovery phase
# Appeal launched 26 March 2014
# Guinea MDRGN007 25Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 25Jul2016.txt
# 69449
# Emergency appeal n MDRUA007 GLIDE n OT-2013-000151-UKR
# Operations update n 6
# Date of issue: 30 May 2
# Ukraine MDRUA007 30May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ukraine MDRUA007 30May2016.txt
# 22514
# DREF operation final report Operation MDRMK003
# Date of issue: 11 June 2015 Glide n CW-2014-000171-MK
# Macedonia, the former Yugoslav Republic of MDRMK003 11Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK003 11Jun2015.txt
# 54101
# Distribution of food kits to the affected population, La Paz River
# in Mecapaca Source: Bolivian Red
# Bolivia MDRBO010 28Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bolivia MDRBO010 28Feb2016.txt
# 37691
# Emergency appeal n MDRPK011 Glide number: FL-2015-000090-PAK
# Date of issue: 29 July 2016 Date of dis
# Pakistan MDRPK011 29Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Pakistan MDRPK011 29Jul2016.txt
# 43339
# Emergency Appeal n MDRLK005 GLIDE n FL-2016-000050-LKA
# Operation update n 3 (6-month consolidated re
# Sri Lanka MDRLK005 22Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sri Lanka MDRLK005 22Dec2016.txt
# 15098
# Emergency appeal n MDRNA009 GLIDE n DR-2015-000130-NAM
# Operations update n 2 Timeframe covered by th
# Namibia MDRNA009 12Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Namibia MDRNA009 12Nov2015.txt
# 21822
# Emergency Appeal n MDRMM006 Glide n FL-2015-000080-MMR & FL-2015-000089-MMR
# Date of issue: 11 August
# Myanmar MDRMM006 11Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Myanmar MDRMM006 11Aug2015.txt
# 29286
# DREF n MDRCV002 GLIDE n VO-2014-000158-CPV
# Operations update n 2; 13 February 2015 Timeframe covered
# Cape Verde MDRCV002 13Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cape Verde MDRCV002 13Feb2015.txt
# 37939
# Revised Appeal n MDRPH020
# Glide n TC-2015-000168-PHL
# and TC-2015-000170-PHL
# 45,000 people to be assi
# Philippines MDRPH020 08Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH020 08Mar2016.txt
# 42706
# DREF operation Glide n EP-2016-000015-TGO
# Date of issue: 29 September 2016 Date of disaster: 1 Febru
# Togo MDRTG006 29Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Togo MDRTG006 29Sep2016.txt
# 23511
# DREF Operation n MDRGW002
# Date of Issue: 4 May, 2015 Glide n EP-2014-000039-GNB
# Operation start date
# Guinea Bisau MDRGW002 04May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea Bisau MDRGW002 04May2015.txt
# 44991
# 6 March 2015 - Combined Ebola Operations Update No
# 171
# Summary
# IFRCs Ebola strategic framework is
# or
# Africa regional office MDR60002 06Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Africa regional office MDR60002 06Mar2015.txt
# 22631
# Revised Emergency Appeal
# n MDRMN005
# Glide n CW-2016-000004-MNG
# 27,000 people to be assisted
# CHF 158,
# Mongolia MDRMN005 25Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Mongolia MDRMN005 25Jul2016.txt
# 17991
# Red Cross volunteers distribute
# relief items following the floods
#  Red Cross Society of Guinea
# DREF
# Guinea MDRGN008 19Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN008 19Oct2015.txt
# 22470
# Emergency appeal MDRET0016
# EPoA update n 1
# GLIDE n DR-2015-000109-ETH
# Date of Issue: 25 January 2016
# Ethiopia MDRET016 25Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET016 25Jan2016.txt
# 29515
# December 2016: The IFRC Emergency Appeal is
# revised to support SARC reach up to 13 million people
# ov
# Syria MDRSY003 31Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Syria MDRSY003 31Dec2016.txt
# 103912
# Pacific regional office
# Annual Report
# MAA55001
# 30 April 2015
# This report covers the
# period 1 January
# Suva country cluster MAA55001 30Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Suva country cluster MAA55001 30Apr2015.txt
# 21443
# Emergency appeal n MDRSN010 GLIDE n EP-2014-000039-SEN
# Operations update n 14 Timeframe covered by t
# Senegal MDRSN010 28Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Senegal MDRSN010 28Feb2015.txt
# 4046
# Date of issue: 24 August 2016
# Date of disaster:
# 24 August 2016
# Point of contact: Ruben Romero, DM Co
# Italy IB24082016 24Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy IB24082016 24Aug2016.txt
# 27585
# DREF Operation Final Report Operation n MDRMK006
# Date of issue: 17 February 2016 Date of disaster: 3
# Macedonia, the former Yugoslav Republic of MDRMK006 17Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK006 17Feb2016.txt
# 32750
# The Red Crescent Society staff and volunteers distribute humanitarian goods to the
# affected populati
# Kazakhstan MDRKZ008 20Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kazakhstan MDRKZ008 20Oct2015.txt
# 62652
# Overview
# 2014 was a quiet year for Viet Nam in terms of natural disasters, allowing the Viet Nam Red
# Viet Nam MAAVN001 27Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Viet Nam MAAVN001 27Apr2015.txt
# 62179
# DREF operation Operation n MDRMG011
# Date of Issue:30 September, 2015 Date of disaster: 16 January, 2
# Madagascar MDRMG011 30Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Madagascar MDRMG011 30Sep2015.txt
# 53209
# Combined Ebola Operations Update
# No
# 231
# Reporting period: 1  28 June 2015
# Summary
# IFRCs Ebola strate
# Guinea MDRGN007 07Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 07Jul2015.txt
# 4852
# Date of issue: 30 October 2016
# Date of disaster:
# 30 October 2016
# Point of contact: Ruben Romero, DM
# Italy IB301016 30Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy IB301016 30Oct2016.txt
# 23409
# Emergency Appeal MDRZW011 6 months summary update
# Date of issue: 28 April 2016 Timeframe covered by
# Zimbabwe MDRZW011 09May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Zimbabwe MDRZW011 09May2016.txt
# 25166
# 1
# DREF n MDRUA008 GLIDE n AC-2015-000154-UKR
# EPoA update n 1; date of issue: 30 December 2015 Timefr
# Ukraine MDRUA008 30Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ukraine MDRUA008 30Dec2015.txt
# 33924
# DREF Operation n MDRKP007 Glide n FL-2015-000113-PRK
# Date of issue: 24 May 2016 Reporting period: 21
# Democratic People Republic of Korea MDRKP007 24May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic People Republic of Korea MDRKP007 24May2016.txt
# 17893
# Summary:
# On 26 October 2015 at 14:09h local time, an
# earthquake of magnitude 7.5 struck North West
# P
# Pakistan MDRPK012 27Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Pakistan MDRPK012 27Nov2015.txt
# 44247
# Combined Monthly Ebola Operations Update
# No
# 341
# 30 June 2016
# Current epidemiological situation,
# coun
# Guinea MDRGN007 30Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 30Jun2016.txt
# 26978
# KPMG SA
# Geneva, 14 November 2016
# Ref. PHP/VF
# International Federation of Red Cross
# and Red Crescent
# Philippines MDRPH014 22Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH014 22Nov2016.txt
# 32279
# DREF operation n
# o
# MDRVN013 Glide n
# o
# DR-2015-000180-VNM
# Date of issue: 8 April 2016 Date of disaste
# Viet Nam MDRVN013 08Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Viet Nam MDRVN013 08Apr2016.txt
# 11585
# DREF n MDRVU002 GLIDE n TC-2015-000020-VUT
# EPoA update n 1 Date of issue: 16 March 2015
# Operation st
# Vanuatu MDRVU002 16Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Vanuatu MDRVU002 16Mar2015.txt
# 31351
# Revised Emergency Appeal n4
# MDRLR001
# Glide n EP-2014-000039-LBR
# 3.8m million people to be assisted
# C
# Liberia MDRLR001 28Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 28Jun2015.txt
# 37446
# Information bulletin n 6 Brief situation update at 1 February 2016
# The situation
# As of today, more t
# Europe IB010216 01Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Europe IB010216 01Feb2016.txt
# 31011
# DREF operation n MDRCM022 Glide n EP-2015-000156-CMR
# Date of Issue: Date of disaster: November 2015
#
# Cameroon MDRCM022 29Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Cameroon MDRCM022 29Apr2016.txt
# 15884
# P a g e | 1
# DREF operation n MDRLA004 GLIDE n FF-2016-000093-LAO
# DREF operation update n 1 Date of d
# Laos MDRLA004 23Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Laos MDRLA004 23Sep2016.txt
# 18809
# DREF Operation n MDRMK003 Glide n CW-2014-000171-MKD
# Date of issue: 15 January 2015 Expected timefra
# Macedonia, the former Yugoslav Republic of MDRMK003 15Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK003 15Jan2015.txt
# 43433
# Emergency appeal MDRSO005 GLIDE n DR-2015-000134-SOM
# EPoA update n 3
# Date of issue: 08 September 201
# Somalia MDRSO005 08Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Somalia MDRSO005 08Sep2016.txt
# 12343
# Emergency Appeal no. MDRCF017 Glide n OT-2013-000152.CAF
# Date of Launch: 14 February 2014 Expected e
# Central African Republic MDRCF017 19Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Central African Republic MDRCF017 19Oct2015.txt
# 26289
# Revised Emergency Appeal n MDRTZ017
# Glide n EP-2015-000052-TZA
# 250,000 people to be assisted
# CHF 5,2
# Tanzania MDRTZ017 20Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ017 20Jan2016.txt
# 25404
# DREF Operation MDRRS011 Glide n OT-2015-000069-SRB
# Date of issue: 18 August 2015 Expected timeframe:
# Serbia MDRRS011 18Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Serbia MDRRS011 18Aug2015.txt
# 69812
# 1
# Revised appeal n MDRNP008 GLIDE n EQ-2015-000048-NPL
# Operation update n 9 Date of issue: 25 Februa
# Nepal MDRNP008 25Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal MDRNP008 25Feb2016.txt
# 23797
# DREF Operation MDRIN014 GLIDE n FL-2014-000117-IND
# Update n 2; date of issue: 9 March 2015 Timeframe
# India MDRIN014 09Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/India MDRIN014 09Mar2015.txt
# 58451
# 1
# Preliminary DREF operation final report
# Operation n MDRSI002
# Glide n OT-2015-000069-SVN
# Date of is
# Slovenia MDRSI002 20Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Slovenia MDRSI002 20Jun2016.txt
# 48447
# Emergency appeal n MDRMM006 GLIDE n FL-2015-000080-MMR & FL-2015-000089-MMR
# Operations update n 3
# Is
# Myanmar MDRMM006 17Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Myanmar MDRMM006 17Mar2016.txt
# 44247
# Combined Monthly Ebola Operations Update
# No
# 341
# 30 June 2016
# Current epidemiological situation,
# coun
# Liberia MDRLR001 30Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 30Jun2016.txt
# 47452
# P a g e | 1
# Emergency Plan of Action (EPoA)
# El Salvador: Drought 2015
# Operation MDRSV009
# Date of iss
# El Salvador MDRSV009 23Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/El Salvador MDRSV009 23Apr2016.txt
# 38501
# Emergency Appeal MDRIQ006 Glide n OT-2014-000074-IRQ
# Host National Society: Iraqi Red Crescent Socie
# Iraq MDRIQ006 19Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Iraq MDRIQ006 19Apr2015.txt
# 35687
# DREF operation n MDRBD015 Glide n TC-2015-000101-BGD
# Date of issue: 11 August 2015 Expected timefram
# Bangladesh MDRBD015 12Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD015 12Aug2015.txt
# 50654
# 1
# Emergency Appeal Operation n MDRSO002 Glide n TC-2013-000140-SOM
# Date of Issue: 23 February 2015 D
# Somalia MDRSO002 23Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Somalia MDRSO002 23Feb2015.txt
# 30425
# P a g e | 1
# DREF Operation n MDRAF002 Glide n FF-2014-000060-AFG
# DREF final report; issued on 11 May
# Afghanistan MDRAF002 11May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Afghanistan MDRAF002 11May2015.txt
# 48989
# DREF operation n MDRUG032
# GLIDE n EP-2013-000058
# 19 February, 2015
# The International Federation of R
# Uganda MDRUG032 20Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Uganda MDRUG032 20Feb2015.txt
# 47390
# 2 April 2015 - Combined Ebola Operations Update No
# 191
# 16  29 March 2015
# Summary
# IFRCs Ebola strateg
# Nigeria MDRNG017 02Apr2015.txt
# ...
# 57142
# Overview
# Through the Long Term Planning Framework (LTPF) 2012-15, the International Federation of Re
# Democratic People Republic of Korea MAAKP002 30Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic People Republic of Korea MAAKP002 30Apr2015.txt
# 48984
# Emergency Appeal: MDRGM010 Glide number: OT-2015-000021-GMB
# Date of Issue: 31 October 2016 Date of d
# Gambia MDRGM010 31Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Gambia MDRGM010 31Oct2016.txt
# 54980
# Rapid needs assessment in Chaychi village, Kara-Suu district.
# Photo: Kyrgyzstan RC
# DREF Operation Fi
# Kyrgyzstan MDRKG011 20Jun2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kyrgyzstan MDRKG011 20Jun2016.txt
# 20360
# Emergency appeal n MDRGM010 GLIDE n OT-2015-000021-GMB
# Operations update n 2 Timeframe covered by th
# Gambia MDRGM010 30Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Gambia MDRGM010 30Jun2015.txt
# 58576
# International appeal n MDR55001 GLIDE n TC-2015-000020-VUT
# Operations update n 2
# 15 May 2015
# Timefra
# Suva country cluster MDR55001 15May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Suva country cluster MDR55001 15May2015.txt
# 20074
# DREF Operation no
# MDRPH022 Glide n TC-2016-000110-PHL
# Date of issue: 19 October 2016 Date of disaste
# Philippines MDRPH022 19Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH022 19Oct2016.txt
# 7850
# Date of issue: 12 February 2016 GLIDE n FL-2016-000009-IDN
# Date of disaster: 7 February 2016 (ongoin
# Indonesia 0 12Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Indonesia 0 12Feb2016.txt
# 48528
# Emergency Appeal: MDRTZ018 Operation n
# Date of Issue: 30 November 2016 Glide number: EP-2015-000058-
# Tanzania MDRTZ018 30Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ018 30Nov2016.txt
# 32698
# International Federation of Red Cross
# and Red Crescent Societies (IFRC), Geneva
# Independent Auditors
# Guinea MDRGN007 05Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guinea MDRGN007 05Apr2016.txt
# 39452
# DREF Operation: Peru: Floods and Landslides MDRPE008
# Glide No. FL-2015-000011-PER
# Date issued: 07 Ap
# Peru MDRPE008 08Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Peru MDRPE008 08Apr2015.txt
# 35209
# DREF Operation n MDRCD017 Date of Issue: 10 November 2016
# Date of issue: 18 November 2016 Operation
# Democratic Republic of Congo MDRCD017 18Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic Republic of Congo MDRCD017 18Nov2016.txt
# 9094
# 1
# Information Bulletin n 1
# 1 April 2015
# This bulletin is being issued for information only, and refl
# Philippines 0 01Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines 0 01Apr2015.txt
# 18199
# Appeal n MDRMW012 10,000 people to be assisted Appeal launched September 2015
# 74,900 Swiss franc DRE
# Malawi MDRMW012 18Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Malawi MDRMW012 18Sep2015.txt
# 61669
# Emergency Appeal Operation no. MDRDM002
# Date of Issue: 23 August 2016 Glide number: TC-2015-000119-D
# Dominica MDRDM002 24Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Dominica MDRDM002 24Aug2016.txt
# 93955
# This Operations Update no. 2 is to report on the implementation progress of activities under the
# rev
# Greece MDRGR001 20Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Greece MDRGR001 20Jan2016.txt
# 31500
# Revised appeal n MDRMK005 250,000 people to be assisted Appeal launched 10 September 2015
# Glide no.
# Macedonia, the former Yugoslav Republic of MDRMK005 10Feb2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Macedonia, the former Yugoslav Republic of MDRMK005 10Feb2016.txt
# 37941
# Emergency Appeal : MDRIQ006 Glide n: OT-2014-000074-IRQ
# Host National Society: Iraqi Red Crescent So
# Iraq MDRIQ006 03Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Iraq MDRIQ006 03Nov2015.txt
# 49472
# Operation Update no. 2 Emergency appeal no. MDRCR014
# GLIDE no. OT-2015- 000157-CRI
# Date of Issue: 30
# Costa Rica MDRCR014 31Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Costa Rica MDRCR014 31Oct2016.txt
# 38356
# Revised Emergency Appeal n
# MDRSL005
# Glide n EP-2014-000039-SLE
# 6.3 million people to be assisted
# CHF
# Sierra Leone MDRSL005 24Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Sierra Leone MDRSL005 24Jun2015.txt
# 41775
# Emergency appeal n : MDRIQ007 GLIDE n: OT-2014-000074-IRQ
# Operations update n : 1 Timeframe covered
# Iraq MDRIQ007 24Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Iraq MDRIQ007 24Mar2016.txt
# 10496
# bo.ifrc.org > Public Folders > General Information > Reports Publishing > Public Web Site and FedNet
# Suva country cluster MDR55001 25Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Suva country cluster MDR55001 25Mar2015.txt
# 20972
# Appeal History:
#  This Emergency Appeal was launched on 30 December, 2014 for CHF 1,050,574 for 9 mon
# Ethiopia MDRET015 05Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET015 05Feb2015.txt
# 24395
# International Federation of Red Cross
# and Red Crescent Societies (IFRC), Geneva
# Independent Auditors
# Philippines MDRPH014 16Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH014 16Feb2015.txt
# 22727
# Emergency Appeal Operation n: MDRUG038 Glide n: OT-2016-000087-UGA
# EPoA update n 2: 28th September 2
# Uganda MDRUG038 28Sep2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Uganda MDRUG038 28Sep2016.txt
# 45230
# Emergency Appeal: Population Movement Operation n:MDRB1008
# Date of Issue:23 February, 2015 Glide n:O
# Burundi MDRBI008 23Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Burundi MDRBI008 23Feb2015.txt
# 27631
# DREF n MDRET017 Glide n FL-2016-000045-ETH
# Date of issue: 20 May 2016 Expected timeframe: 3 months
# E
# Ethiopia MDRET017 20May2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET017 20May2016.txt
# 56470
# Final report
# Emergency appeal n MDRPH011
# GLIDE n TC-2012-000197-PHL
# 2 April 2015
# Period covered by t
# Philippines MDRPH011 02Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH011 02Apr2015.txt
# 42065
# Emergency Appeal: Operation n MDRTZ018 Glide n EP-2015-000058-TZA
# Date of Issue: 30 November 2016 Da
# Tanzania MDRTZ018 30Oct2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ018 30Oct2016.txt
# 6528
# 1
# Emergency Appeal MDRNP008
# GLIDE no EQ-2015-000048-NPL
# Operation Update no 11
# Issue on: 8 July 2016
# Nepal MDRNP008 08Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal MDRNP008 08Jul2016.txt
# 22391
# DREF Operation Operation n MDRTD014
# Date of issue: 23 January, 2015 Date of disaster 13 January,2015
# Chad MDRTD014 23Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Chad MDRTD014 23Jan2015.txt
# 53766
# Sensitization activities to celebrate Hand washing day event on 15 October 2014 Source: IFRC
# Cholera
# Port au Prince country cluster MDR49008 06Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Port au Prince country cluster MDR49008 06Jul2015.txt
# 11284
# Emergency responders from the Red Cross trained in first aid
# and search and rescue have been mobiliz
# Nepal 0 26Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nepal 0 26Apr2015.txt
# 25952
# P a g e | 1
# Emergency DREF Storm Surge
# DREF for replenishment
# MDRSV008
# Date issued: 15 May 2015 Date
# El Salvador MDRSV008 16May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/El Salvador MDRSV008 16May2015.txt
# 43625
# Overview
# Throughout 2014, the regional office continued working in 15 countries in Eastern Africa an
# Nairobi country cluster MAA64003 30Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nairobi country cluster MAA64003 30Apr2015.txt
# 46881
# Emergency appeal n MDRKE039 GLIDE n DR-2016-000118-KEN
# Operation Update n 1 Timeframe covered by thi
# Kenya MDRKE039 08Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kenya MDRKE039 08Dec2016.txt
# 19601
# DREF Operation n MDRKP007 Date of Disaster: 1-5 August and 21-23 August 2015
# DREF Update n 2
# Date of
# Democratic People Republic of Korea MDRKP007 22Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic People Republic of Korea MDRKP007 22Dec2015.txt
# 107334
# Emergency Appeal no. MDRPY016 GLIDE no. FL-2014-000007-PRY
# Date of issue: 23 November 2015 Date of d
# Paraguay MDRPY016 24Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Paraguay MDRPY016 24Nov2015.txt
# 21391
# Emergency appeal n MDRPH020 GLIDE n TC-2015-000168-PHL and TC-2015-
# 000170-PHL
# Operations update n 3
# Philippines MDRPH020 28Nov2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MDRPH020 28Nov2016.txt
# 22247
# DREF operation MDRPG005 GLIDE n CW-2015-000116-PNG
# DREF update n 2 Timeframe covered by this update:
# Papua New Guinea MDRPG005 21Dec2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Papua New Guinea MDRPG005 21Dec2015.txt
# 45391
# Op
# Da
# Po
# dire
# Op
# Re
# Nu
# Ho
# Re
# Inte
# So
# the
# Cro
# Oth
# Em
# Fo
# Dir
# the
# The
# Re
# Re
# Hu
# Su
# Co
# From
# com
# perations
# Paraguay MDRPY018 02Dec2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Paraguay MDRPY018 02Dec2016.txt
# 8010
# 1
# Information Bulletin n 1
# GLIDE n 1 TC-2015-000051-PHL
# 10 May 2015
# This bulletin is being issued fo
# Philippines 0 10May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines 0 10May2015.txt
# 21026
# DREF Operation n MDRMY002 Glide n FL-2014-000168-MYS
# DREF update n 1: 21 January 2015 Timeframe cove
# Malaysia MDRMY002 21Jan2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Malaysia MDRMY002 21Jan2015.txt
# 27230
# Emergency Appeal Appeal n MDRTZ017;Glide n OT-2015-000052-
# TZA
# Operations update n 2 Period covered
# Tanzania MDRTZ017 01Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Tanzania MDRTZ017 01Jul2015.txt
# 38988
# Ebola Preparedness Fund Operation n MDR64007
# Date of Issue: 27 January 2016 Glide number:
# Operation
# Nairobi country cluster MDR64007 27Jan2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nairobi country cluster MDR64007 27Jan2016.txt
# 17608
# 1
# Emergency Appeal n MDRBD015 Glide n TC-2015-000101-BGD
# Date of issue: 24 August 2015 Date of disas
# Bangladesh MDRBD015 25Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh MDRBD015 25Aug2015.txt
# 6840
# Information bulletin no 1 Date of issue: 29 July 2016
# This bulletin is being issued for information
# Bangladesh 0 29Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Bangladesh 0 29Jul2016.txt
# 34919
# DREF operation Operation n MDRRW011; Glide n FL-2015-000042-RW
# Date of Issue: 30 September, 2015. Da
# Rwanda MDRRW011 30Sep2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Rwanda MDRRW011 30Sep2015.txt
# 25005
# P a g e | 1
# DREF Operation n MDRKP007
# Date of issue: 21 August 2015 Date of Disaster: 1-5 August 201
# Democratic People Republic of Korea MDRKP007 21Aug2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Democratic People Republic of Korea MDRKP007 21Aug2015.txt
# 14535
# Appeal n MDRBY006 10,000 people to be assisted Appeal launched 3 June 2015
# Glide n OT-2014-000146-BL
# Belarus MDRBY006 03Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Belarus MDRBY006 03Jun2015.txt
# 55253
# DREF operation MDRPG005 GLIDE n CW-2015-000116-PNG
# Date of issue: 29 July 2016 Date of disaster: 31
# Papua New Guinea MDRPG005 29Jul2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Papua New Guinea MDRPG005 29Jul2016.txt
# 36296
# Colombian Red Cross volunteers discussing household protection and vector
# control during a community
# - Global - MDR42003 04Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/- Global - MDR42003 04Mar2016.txt
# 70437
# Page | 1
# DREF Final Report
# Guatemala: Earthquake
# DREF Operation MDRGT006 GLIDE no. EQ-2014-000096-GT
# Guatemala MDRGT006 17Jul2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Guatemala MDRGT006 17Jul2015.txt
# 37871
# A beneficiary of the cash transfer program in South Horr
# receiving cash. Photo/Poul Nielsen/Danish R
# Kenya MDRKE030 14May2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kenya MDRKE030 14May2015.txt
# 24054
# DREF Operation Operation n MDRKE032
# Date of issue: 11 March 2015 Date of disaster: 22 November 2014
#
# Kenya MDRKE032 11Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Kenya MDRKE032 11Mar2015.txt
# 10127
# Date of issue: 26 August 2016 Glide No. EQ-2016-000095-ITA
# Date of disaster: 24 August 2016 Point of
# Italy 26082016 26Aug2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Italy 26082016 26Aug2016.txt
# 43298
# 20 March 2015 - Combined Ebola Operations Update No
# 181
# 1  15 March 2015
# Summary
# IFRCs Ebola strateg
# Africa regional office MDR60002 20Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Africa regional office MDR60002 20Mar2015.txt
# 36663
# Emergency appeal n : MDRIQ008 GLIDE n: OT-2014-000074-IRQ
# Six month update Timeframe covered by this
# Iraq MDRIQ008 02Jan2017.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Iraq MDRIQ008 02Jan2017.txt
# 27508
# DREF Operation n MDRSI002 Glide n OT-2015-000069-SVN
# Date of issue: 3 October 2015 Date of disaster
# Slovenia MDRSI002 09Oct2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Slovenia MDRSI002 09Oct2015.txt
# 46870
# Combined Ebola Operations Update
# No
# 221
# Reporting period: 11 May  31 May 2015
# Summary
# IFRCs Ebola st
# Liberia MDRLR001 16Jun2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 16Jun2015.txt
# 41791
# 20 February, 2015 - Combined Ebola Operations Update No
# 161
# Summary
# IFRCs Ebola strategic framework
# Liberia MDRLR001 20Feb2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Liberia MDRLR001 20Feb2015.txt
# 23962
# Emergency appeal MDRPK010 GLIDE n FL-2014-000122-PAK
# Operations update n 2 Timeframe covered by this
# Pakistan MDRPK010 18Mar2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Pakistan MDRPK010 18Mar2015.txt
# 35464
# Emergency Plan of Action (EPoA)
# Paraguay: Floods
# DREF Operation no. MDRAR009 Glide N. FL-2015-000110
# Argentina MDRAR009 20Mar2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Argentina MDRAR009 20Mar2016.txt
# 8611
# Information bulletin n 2
# Date of issue: 21 April 2016
# GLIDE n EQ-2016-000033-JPN
# This bulletin is be
# Japan 0 21Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Japan 0 21Apr2016.txt
# 32674
# Overview
# In 2014, the Philippine Red Cross (PRC) intensified its operations to support the recovery
# Philippines MAAPH001 27Apr2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Philippines MAAPH001 27Apr2015.txt
# 38758
# DREF operation n: MDRNG019 Glide number: NA
# Date of Issue: 20 November 2015 Date of disaster: 15 Feb
# Nigeria MDRNG019 20Nov2015.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Nigeria MDRNG019 20Nov2015.txt
# 59775
# Emergency appeal n MDRET015 GLIDE n OT-2014-000001-ETH
# Operations update : 12 Months Timeframe cover
# Ethiopia MDRET015 27Apr2016.txt
# /home/alice/Documents/Project/info_extraction/scraped_data/corpus/Ethiopia MDRET015 27Apr2016.txt

# %%
kddcorpus = nltk.corpus.PlaintextCorpusReader(CORPUS, '.*\.txt')
kddcorpus
# Out:
# <PlaintextCorpusReader in '/home/alice/Documents/Project/info_extraction/scraped_data/corpus'>

# %%
words = nltk.FreqDist(kddcorpus.words())
count = sum(words.values())
vocab = len(words)

print("Corpus contains a vocabulary of {} and a word count of {}.".format(
    count, vocab
))
# Out:
# Corpus contains a vocabulary of 7796263 and a word count of 58104.

# %%
# Calculations and logic from http://www.kdnuggets.com/faq/precision-recall.html

def metrics(truth,run):
    truth = truth
    run = run
    TP = float(len(set(run) & set(truth)))

    if float(len(run)) >= float(TP):
        FP = len(run) - TP
    else:
        FP = TP - len(run)
    TN = 0
    if len(truth) >= len(run):
        FN = len(truth) - len(run)
    else:
        FN = 0

    accuracy = (float(TP)+float(TN))/float(len(truth))
    recall = (float(TP))/float(len(truth))
    precision = float(TP)/(float(FP)+float(TP))
    print "The accuracy is %r" % accuracy
    print "The recall is %r" % recall
    print "The precision is %r" % precision

    d = {'Predicted Negative': [TN,FN], 'Predicted Positive': [FP,TP]}
    metricsdf = pd.DataFrame(d, index=['Negative Cases','Positive Cases'])

    return metricsdf
# Out:
#   File "<ipython-input-52-e862c503913a>", line 21
#     print "The accuracy is %r" % accuracy
#                              ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print
print
str1 = "NLTK Standard NERC Tool Metrics"

print str1.center(40, ' ')
print
print
metrics(p19Authors['authors'], [re.sub('\*',"",l) for l in nltkents['p19.txt']['persons']])

# %%
print
print
str2 = "Stanford NERC Tool Metrics"

print str2.center(40, ' ')
print
print
metrics(p19Authors['authors'], [re.sub('\*',"",l) for l in stanents['p19.txt']['persons']])

# %%
print
print
str3 = "Polyglot NERC Tool Metrics"

print str3.center(40, ' ')
print
print
metrics(p19Authors['authors'],polyents['p19.txt']['persons'])

# %% [markdown]
# # A Simple Ensemble Classifier

# %%
# Create intersection of true authors from NLTK standard output
a =set(sorted(nltkents['p19.txt']['persons'])) & set(p19Authors['authors'])

# Create intersection of true authors from Stanford NER output
b =set(sorted(stanents['p19.txt']['persons'])) & set(p19Authors['authors'])

# Create intersection of true authors from Polyglot output
c = set(sorted(polyents['p19.txt']['persons'])) & set(p19Authors['authors'])

# Create union of all true positives from each NERC output
(a.union(b)).union(c)

# %%
# Add ensemble results for author to the nested python dictionary; use our functions
p19={'docName':'p19.txt','ensembleAuthors':list((a.union(b)).union(c)),
     'body':list(sectpull(['p19.txt'], section='body'))[0][1],'title':list(titles(['p19.txt']))[0]}

# covert nested dictionary to json for open data storage
# json can be stored in mongodb or any other disk store
output = json.dumps(p19, ensure_ascii=False,indent=3)

# print out the authors section we just created in our json
print json.dumps(json.loads(output)['ensembleAuthors'],indent=3)

# uncomment to see full json output
#print json.dumps((json.loads(output)),indent=3)
